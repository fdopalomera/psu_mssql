# %%
from class_PrepPsuAccess import PrepPsuAccess
from sqlalchemy import create_engine

# %% [markdown]
# # 1. Declaración de variables a utilizar en proceso de ETL

# %%
# Conexión a sql server 
servername = 'localhost'
database = 'psu'
engine = create_engine('mssql://{}/{}?trusted_connection=yes&driver=ODBC+Driver+13+for+SQL+Server'.format(servername, database))

# %%
# Diccionario con nombres de columnas a cambiar, dependiendo de la tabla
colname_dict = {
    'b': {'INGRESO_FAMILIAR': 'INGRESO_BRUTO_FAMILIAR',
         'INGRESO_BRUTO_FAM': 'INGRESO_BRUTO_FAMILIAR'},
    'e': {'POND_ANO_ACAD': 'POND_AÑO_ACAD'},
    'c': {'PTJE_LENGUAJE_Y_COMUNICACION': 'PTJE_LENGUAJE_Y_COMUNICACION_ACTUAL'}
}
# Diccionario con valores nulos de las tablas e
null_e = {
    'PTJE_RANKING': 0, 
    'PTJE_NEM': 0,
    'LENGUAJE_Y_COMUNICACION': 0,
    'MATEMATICA': 0, 
    'CIENCIAS': 0, 
    'HISTORIA_Y_CIENCIAS_SOCIALES': 0, 
    'LOCAL_EDUCACIONAL': 0, 
    'PROMEDIO_DE_NOTAS': 0, 
    'UNIDAD_EDUCATIVA': 0, 
    'CODIGO_REGION': 0, 
    'CODIGO_PROVINCIA': 0, 
    'CODIGO_COMUNA': 0,
    'INGRESO_BRUTO_FAMILIAR': 0,
    'SEXO': 0,
    'PUNTAJE_PONDERADO': 0
}
# Diccionario con valores nulos de las tablas c
null_c = {
    'PTJE_RANKING': 0, 
    'PTJE_NEM': 0,
    'PTJE_LENGUAJE_Y_COMUNICACION_ACTUAL': 0,
    'PTJE_MATEMATICA_ACTUAL': 0, 
    'PTJE_CIENCIAS_ACTUAL': 0, 
    'PTJE_HISTORIA_Y_CIENCIAS_SOCIALES_ACTUAL': 0, 
    'LOCAL_EDUCACIONAL': 0, 
    'PROMEDIO_NOTAS': 0, 
    'UNIDAD_EDUCATIVA': 0, 
    'CODIGO_REGION': 0, 
    'CODIGO_PROVINCIA': 0, 
    'CODIGO_COMUNA': 0
}
# Diccionario con valores nulos de las tablas a
null_a = {
    'AÑO_PROCESO': 0,
    'LOCAL_EDUCATIVA': 0,
    'UNIDAD_EDUCATIVA': 0,
    'CODIGO_COMUNA': 0
}
# Diccionario con valores nulos de las tablas b
null_b = {
    'INGRESO_BRUTO_FAMILIAR': 0
}
# Diccionario con los diccionarios de valores nulos por tabla
null_dict = {'e': null_e,
            'c': null_c,
            'b': null_b,
            'a': null_a}
# Diccionario con los tipo de datos deseados por columna, para la tabla e
dtypes_e = {
    'AÑO_PROCESO': int, 
    'NACIONALIDAD': int, 
    'PREFERENCIA': int, 
    'SEXO': int, 
    'CODIGO': int, 
    'ESTADO_DE_POSTULACION': int, 
    'LUGAR_EN_LA_LISTA': int, 
    'PUNTAJE_PONDERADO': float, 
    'LOCAL_EDUCACIONAL': int, 
    'SITUACION_EGRESO_EDUCACIONAL': int, 
    'ROL_BASE_DATOS': int, 
    'UNIDAD_EDUCATIVA': int, 
    'COD_ENSENANZA': int, 
    'GRUPO_DEPENDENCIA': int, 
    'CODIGO_PROVINCIA': int, 
    'CODIGO_REGION': int, 
    'AÑO_DE_EGRESO': int, 
    'CODIGO_COMUNA': int, 
    'PROMEDIO_DE_NOTAS': float, 
    'PTJE_NEM': int, 
    'LENGUAJE_Y_COMUNICACION': int, 
    'PTJE_RANKING': int, 
    'HISTORIA_Y_CIENCIAS_SOCIALES': int, 
    'MATEMATICA': int, 
    'CIENCIAS': int, 
    'PERCENTIL_LM': float, 
    'PROM_LM': float, 
    'INGRESO_BRUTO_FAMILIAR': int, 
    'COD_REGION': int, 
    'COD_COMUNA': int, 
    'COD_PROVINCIA': int, 
    'NRO_TARJETA_DE_MATRICULA': int, 
    'Id': int, 
    'POND_AÑO_ACAD': int,
    'SEXO': int,
    'PUNTAJE_PONDERADO': float
}
# Diccionario con los tipo de datos deseados por columna, para la tabla c  
dtypes_c = {
    'PTJE_RANKING': int, 
    'PTJE_NEM': int,
    'PTJE_LENGUAJE_Y_COMUNICACION_ACTUAL': int,
    'PTJE_MATEMATICA_ACTUAL': int, 
    'PTJE_CIENCIAS_ACTUAL': int, 
    'PTJE_HISTORIA_Y_CIENCIAS_SOCIALES_ACTUAL': int,
    'PROM_LM_ACTUAL': float,
    'PROM_LM_ANTERIOR': float,
    'LOCAL_EDUCACIONAL': int, 
    'PROMEDIO_NOTAS': float, 
    'UNIDAD_EDUCATIVA': int, 
    'CODIGO_REGION': int, 
    'CODIGO_PROVINCIA': int, 
    'CODIGO_COMUNA': int}
# Diccionario con los tipo de datos deseados por columna, para la tabla a
dtypes_a = {
    'AÑO_PROCESO': int,
    'LOCAL_EDUCATIVA': int,
    'UNIDAD_EDUCATIVA': int,
    'CODIGO_COMUNA': int
}
# Diccionario con los tipo de datos deseados por columna, para la tabla b
dtypes_b = {'INGRESO_BRUTO_FAMILIAR': int}
# Diccionario con los diccionarios de tipo de dato deseado de aplicar por tabla
dtypes_dict = {'e': dtypes_e,
               'c': dtypes_c,
               'b': dtypes_b,
               'a': dtypes_a}

# %%
# Diccionario con los transformadores deseados de aplicar por columna y por tabla 
transformer_dict = {
    'e': {
        'PUNTAJE_PONDERADO': lambda x: x.str[:3] + '.' + x.str[3:],
        'PROM_LM': lambda x: x.str[:3] + '.' + x.str[3:],
        'PROMEDIO_DE_NOTAS': lambda x: x.str[0] + '.' + x.str[1:],
        'FECHA_NACIMIENTO': lambda x: x.str[:2] + '-' + x.str[2:4] + '-' + x.str[4:]
    },
    'c': {
        'PROMEDIO_NOTAS': lambda x: x.str[0] + '.' + x.str[1:],
        'PROM_LM_ACTUAL': lambda x: x.str[:3] + '.' + x.str[3:],
        'PROM_LM_ANTERIOR': lambda x: x.str[:3] + '.' + x.str[3:]
    }
}

# %% [markdown]
# # 2. Aplicación proceso de ETL

# %% [markdown]
# ## 2.1 PSU 2018

# %%
# Creación de la instancia
file_path = r'C:\Users\fpalomer\Documents\PSU\PSU_2018.mdb'
p18 = PrepPsuAccess(file_path)

# %%
# Paso 1: Limpiar nombre de las columnas
p18.clean_columns_name(print_results=True)

# %%
# Paso 2: Homogeneizar nombre de columnas
p18.rename_columns(colname_dict)

# %%
# Paso 3: Transformaciones varias
p18.transform_col(transformer_dict)

# %%
# Paso 4: Remover valores no númericos en columnas númericas
p18.remove_numeric_dirtydata(dtypes_dict)

# %%
# Paso 5: Cambio tipo de datos
p18.change_column_dtype(dtypes_dict)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1746 entries, 0 to 1745
# Data columns (total 56 columns):
# NUMERO_DOCUMENTO                         1744 non-null object
# TIPO_DE_IDENTIFICACION                   1744 non-null object
# AÑO_PROCESO                              1743 non-null float64
# MATERNO                                  1743 non-null object
# PATERNO                                  1744 non-null object
# NACIONALIDAD                             1743 non-null float64
# NOMBRE                                   1743 non-null object
# PREFERENCIA                              1743 non-null float64
# SEXO                                     1743 non-null float64
# CODIGO                                   1743 non-null float64
# ESTADO_DE_POSTULACION                    1743 non-null float64
# LUGAR_EN_LA_LISTA                        1743 non-null float64
# PUNTAJE_PONDERADO                        1743 non-null float64
# BEA                                      1743 non-null object
# LOCAL_EDUCACIONAL                        1743 non-null float64
# SITUACION_EGRESO_EDUCACIONAL             1743 non-null float64
# ROL_BASE_DATOS                           1743 non-null float64
# UNIDAD_EDUCATIVA                         1743 non-null float64
# COD_ENSENANZA                            1743 non-null float64
# GRUPO_DEPENDENCIA                        1743 non-null float64
# RAMA_EDUCACIONAL                         1743 non-null object
# CODIGO_PROVINCIA                         1743 non-null float64
# CODIGO_REGION                            1743 non-null float64
# AÑO_DE_EGRESO                            1743 non-null float64
# CODIGO_COMUNA                            1743 non-null float64
# PERCENTIL_NOTAS                          1743 non-null object
# PROMEDIO_DE_NOTAS                        1743 non-null float64
# PTJE_NEM                                 1743 non-null float64
# LENGUAJE_Y_COMUNICACION                  1743 non-null float64
# PTJE_RANKING                             1743 non-null float64
# HISTORIA_Y_CIENCIAS_SOCIALES             1743 non-null float64
# MATEMATICA                               1743 non-null float64
# CIENCIAS                                 1743 non-null float64
# MODULO_CIENCIAS                          1560 non-null object
# PERCENTIL_LM                             1743 non-null float64
# PROM_LM                                  1743 non-null float64
# FECHA_NACIMIENTO                         1743 non-null object
# CALLE                                    1743 non-null object
# INGRESO_BRUTO_FAMILIAR                   1743 non-null float64
# BLOCK                                    160 non-null object
# NUMERO                                   1743 non-null object
# DEPARTAMENTO                             203 non-null object
# COD_REGION                               1743 non-null float64
# VILLA/POBLACION                          1333 non-null object
# COD_COMUNA                               1743 non-null float64
# COD_PROVINCIA                            1743 non-null float64
# NOMBRE_COMUNA                            1743 non-null object
# NOMBRE_PROVINCIA                         1743 non-null object
# CIUDAD                                   1743 non-null object
# CELULAR                                  1743 non-null object
# NUMERO_TELEFONO                          1743 non-null object
# EMAIL                                    1743 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    1743 non-null object
# NRO_TARJETA_DE_MATRICULA                 1743 non-null float64
# Id                                       1746 non-null int64
# POND_AÑO_ACAD                            1743 non-null float64
# dtypes: float64(33), int64(1), object(22)
# memory usage: 764.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1281 entries, 0 to 1280
# Data columns (total 53 columns):
# NUMERO_DOCUMENTO                1279 non-null object
# TIPO_DE_IDENTIFICACION          1279 non-null object
# AÑO_PROCESO                     1278 non-null float64
# MATERNO                         1278 non-null object
# PATERNO                         1279 non-null object
# NACIONALIDAD                    1278 non-null float64
# NOMBRE                          1278 non-null object
# PREFERENCIA                     1278 non-null float64
# SEXO                            1278 non-null float64
# CODIGO                          1278 non-null float64
# ESTADO_DE_POSTULACION           1278 non-null float64
# LUGAR_EN_LA_LISTA               1278 non-null float64
# PUNTAJE_PONDERADO               1278 non-null float64
# PASE                            1278 non-null object
# LOCAL_EDUCACIONAL               1278 non-null float64
# SITUACION_EGRESO_EDUCACIONAL    1278 non-null float64
# ROL_BASE_DATOS                  1278 non-null float64
# UNIDAD_EDUCATIVA                1278 non-null float64
# GRUPO_DEPENDENCIA               1278 non-null float64
# RAMA_EDUCACIONAL                1278 non-null object
# CODIGO_PROVINCIA                1278 non-null float64
# CODIGO_REGION                   1278 non-null float64
# AÑO_DE_EGRESO                   1278 non-null float64
# CODIGO_COMUNA                   1278 non-null float64
# PERCENTIL_NOTAS                 1278 non-null object
# PROMEDIO_DE_NOTAS               1278 non-null float64
# PTJE_NEM                        1278 non-null float64
# LENGUAJE_Y_COMUNICACION         1278 non-null float64
# PTJE_RANKING                    1278 non-null float64
# HISTORIA_Y_CIENCIAS_SOCIALES    1278 non-null float64
# MATEMATICA                      1278 non-null float64
# CIENCIAS                        1278 non-null float64
# MODULO_CIENCIAS                 1068 non-null object
# PERCENTIL_LM                    1278 non-null float64
# PROM_LM                         1278 non-null float64
# FECHA_NACIMIENTO                1278 non-null object
# CALLE                           1278 non-null object
# INGRESO_BRUTO_FAMILIAR          1278 non-null float64
# BLOCK                           116 non-null object
# NUMERO                          1278 non-null object
# DEPARTAMENTO                    137 non-null object
# COD_REGION                      1278 non-null float64
# VILLA/POBLACION                 955 non-null object
# COD_COMUNA                      1278 non-null float64
# COD_PROVINCIA                   1278 non-null float64
# NOMBRE_COMUNA                   1278 non-null object
# NOMBRE_PROVINCIA                1278 non-null object
# CIUDAD                          1278 non-null object
# TELEFONO_CELULAR                1278 non-null object
# TELEFONO_FIJO                   1278 non-null object
# EMAIL                           1278 non-null object
# Id                              1281 non-null int64
# NRO_TARJETA_DE_MATRICULA        1278 non-null float64
# dtypes: float64(31), int64(1), object(21)
# memory usage: 530.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19220 entries, 0 to 19219
# Data columns (total 56 columns):
# NUMERO_DOCUMENTO                         19220 non-null object
# TIPO_DE_IDENTIFICACION                   19220 non-null object
# AÑO_PROCESO                              19220 non-null int64
# MATERNO                                  19220 non-null object
# PATERNO                                  19220 non-null object
# NACIONALIDAD                             19220 non-null int64
# NOMBRE                                   19220 non-null object
# PREFERENCIA                              19220 non-null int64
# SEXO                                     19220 non-null int64
# CODIGO                                   19220 non-null int64
# ESTADO_DE_POSTULACION                    19220 non-null int64
# LUGAR_EN_LA_LISTA                        19220 non-null int64
# PUNTAJE_PONDERADO                        19220 non-null float64
# BEA                                      2457 non-null object
# LOCAL_EDUCACIONAL                        19220 non-null int64
# SITUACION_EGRESO_EDUCACIONAL             19220 non-null int64
# ROL_BASE_DATOS                           19220 non-null int64
# UNIDAD_EDUCATIVA                         19220 non-null int64
# COD_ENSENANZA                            19220 non-null int64
# GRUPO_DEPENDENCIA                        19220 non-null int64
# RAMA_EDUCACIONAL                         19213 non-null object
# CODIGO_PROVINCIA                         19220 non-null int64
# CODIGO_REGION                            19220 non-null int64
# AÑO_DE_EGRESO                            19220 non-null int64
# CODIGO_COMUNA                            19220 non-null int64
# PERCENTIL_NOTAS                          19220 non-null object
# PROMEDIO_DE_NOTAS                        19220 non-null float64
# PTJE_NEM                                 19220 non-null int64
# LENGUAJE_Y_COMUNICACION                  19220 non-null int64
# PTJE_RANKING                             19220 non-null int64
# HISTORIA_Y_CIENCIAS_SOCIALES             19220 non-null int64
# MATEMATICA                               19220 non-null int64
# CIENCIAS                                 19220 non-null int64
# MODULO_CIENCIAS                          14203 non-null object
# PERCENTIL_LM                             19220 non-null float64
# PROM_LM                                  19220 non-null float64
# FECHA_NACIMIENTO                         19220 non-null object
# CALLE                                    19220 non-null object
# INGRESO_BRUTO_FAMILIAR                   19220 non-null int64
# BLOCK                                    1996 non-null object
# NUMERO                                   19213 non-null object
# DEPARTAMENTO                             3990 non-null object
# COD_REGION                               19220 non-null int64
# VILLA/POBLACION                          11336 non-null object
# COD_COMUNA                               19212 non-null float64
# COD_PROVINCIA                            19220 non-null int64
# NOMBRE_COMUNA                            19220 non-null object
# NOMBRE_PROVINCIA                         19220 non-null object
# CIUDAD                                   19220 non-null object
# CELULAR                                  19220 non-null object
# NUMERO_TELEFONO                          19220 non-null object
# EMAIL                                    19220 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    19220 non-null object
# NRO_TARJETA_DE_MATRICULA                 19220 non-null int64
# Id                                       19220 non-null int64
# POND_AÑO_ACAD                            19212 non-null float64
# dtypes: float64(6), int64(28), object(22)
# memory usage: 8.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277013 entries, 0 to 277012
# Data columns (total 35 columns):
# Id                                            277013 non-null int64
# TIPO_DE_IDENTIFICACION                        277011 non-null object
# NUMERO_DOCUMENTO                              277011 non-null object
# AÑO_DOCUMENTO                                 277011 non-null object
# SITUACION_EGRESO_EDUCACIONAL                  277011 non-null object
# LOCAL_EDUCACIONAL                             277010 non-null float64
# UNIDAD_EDUCATIVA                              277010 non-null float64
# ROL_BASE_DATOS                                277010 non-null object
# COD_ENSENANZA                                 277010 non-null object
# RAMA_EDUCACIONAL                              276511 non-null object
# GRUPO_DEPENDENCIA                             277010 non-null object
# CODIGO_REGION                                 277010 non-null float64
# CODIGO_PROVINCIA                              277010 non-null float64
# CODIGO_COMUNA                                 277010 non-null float64
# AÑO_EGRESO_ENSEÑANZA_MEDIA                    277010 non-null object
# BEA                                           15423 non-null object
# PACE                                          25058 non-null object
# PROMEDIO_NOTAS                                277010 non-null float64
# PERCENTIL_NOTAS                               277010 non-null object
# PTJE_LENGUAJE_Y_COMUNICACION_ACTUAL           277010 non-null float64
# PTJE_NEM                                      277010 non-null float64
# PTJE_RANKING                                  277010 non-null float64
# PTJE_MATEMATICA_ACTUAL                        277010 non-null float64
# PTJE_HISTORIA_Y_CIENCIAS_SOCIALES_ACTUAL      277010 non-null float64
# PTJE_CIENCIAS_ACTUAL                          277010 non-null float64
# MODULO_CIENCIAS_ACTUAL                        167767 non-null object
# PROM_LM_ACTUAL                                277010 non-null float64
# PERCENTIL_LM_ACTUAL                           277010 non-null object
# PTJE_HISTORIA_Y_CIENCIAS_SOCIALES_ANTERIOR    277010 non-null object
# PTJE_LENGUAJE_Y_COMUNICACION_ANTERIOR         277010 non-null object
# PTJE_MATEMATICA_ANTERIOR                      277010 non-null object
# PTJE_CIENCIAS_ANTERIOR                        277010 non-null object
# MODULO_CIENCIAS_ANTERIOR                      30697 non-null object
# PROM_LM_ANTERIOR                              277010 non-null float64
# PERCENTIL_LM_ANTERIOR                         277010 non-null object
# dtypes: float64(14), int64(1), object(20)
# memory usage: 74.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306265 entries, 0 to 306264
# Data columns (total 67 columns):
# Id                              306265 non-null int64
# TIPO_DE_IDENTIFICACION          306263 non-null object
# NUMERO_DOCUMENTO                306263 non-null object
# AÑO_PROCESO                     306263 non-null object
# PATERNO                         306263 non-null object
# MATERNO                         306262 non-null object
# NOMBRES                         306262 non-null object
# LOCAL                           306262 non-null object
# UED                             306262 non-null object
# RBD                             306262 non-null object
# COD_ENS                         306262 non-null object
# AÑO_EGRESO                      306262 non-null object
# COD_REGION_UED                  306262 non-null object
# COD_PROVINCIA_UED               306262 non-null object
# CALLE                           306262 non-null object
# COD_COMUNA_UED                  306262 non-null object
# NOMBRE_COMUNA_UED               298656 non-null object
# NUMERO                          305964 non-null object
# BLOCK                           27984 non-null object
# COD_REGION                      306262 non-null object
# DEPARTAMENTO                    40380 non-null object
# VILLA/POBLACION                 226324 non-null object
# COD_PROVINCIA                   306262 non-null object
# COD_COMUNA                      306262 non-null object
# NOMBRE_PROVINCIA                306262 non-null object
# NOMBRE_COMUNA                   306262 non-null object
# CIUDAD                          306262 non-null object
# ZONA                            306262 non-null object
# TELEFONO_FIJO                   306262 non-null object
# BEA                             15963 non-null object
# CELULAR                         306262 non-null object
# EMAIL                           306227 non-null object
# PACE                            29428 non-null object
# FECHA_NAC                       306262 non-null object
# RINDE_PROCESO                   306262 non-null object
# SEXO                            306262 non-null object
# AÑOS_LLEGA_CHILE                306262 non-null object
# ESTADO_CIVIL                    306262 non-null object
# PAIS_NACIONALIDAD               306262 non-null object
# TIENES_HIJOS                    306262 non-null object
# CUANTOS_HIJOS                   306262 non-null object
# VIVE_CON_HIJOS                  306260 non-null object
# EMBARAZO_ADOLESCENTE            306253 non-null object
# COD_ETNIA                       306253 non-null object
# HORARIO_TRABAJO                 306255 non-null object
# OCUPACION                       295543 non-null object
# TIENE_TRABAJO_REMUNERADO        306260 non-null object
# HORAS_DEDICA_TRABAJO            306262 non-null object
# ECONOMICAMENTE_ES               306262 non-null object
# TIENE_DISCAPACIDAD              295543 non-null object
# TIPO_DISCAPACIDAD               306262 non-null object
# PERSONAS_GRUPO_FAMILIAR         306262 non-null object
# CON_QUIEN_VIVE                  306261 non-null object
# PERSONAS_TRABAJO_REMUNERADO     306244 non-null object
# PERSONAS_ESTUDIAN_SUPERIOR      305970 non-null object
# ACTIVIDAD_JEFE_FAMILIA          306262 non-null object
# JEFE_DE_FAMILIA                 305945 non-null object
# OTRO_JEFE_FAMILIA               6032 non-null object
# INGRESO_BRUTO_FAMILIAR          306018 non-null float64
# EDUCACION_MADRE                 306262 non-null object
# COMPLETO_EDUCACION_MADRE        275400 non-null object
# EDUCACION_PADRE                 306261 non-null object
# COMPLETO_EDUCACION_PADRE        237425 non-null object
# ESTUDIO_INSTITUCION_SUPERIOR    305980 non-null object
# CARRERA_INSTITUCION_SUPERIOR    37189 non-null object
# TITULACION_CARRERA              37215 non-null object
# NRO_TARJETA_MATRICULA           306262 non-null object
# dtypes: float64(1), int64(1), object(65)
# memory usage: 156.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1746 entries, 0 to 1745
# Data columns (total 56 columns):
# NUMERO_DOCUMENTO                         1744 non-null object
# TIPO_DE_IDENTIFICACION                   1744 non-null object
# AÑO_PROCESO                              1743 non-null float64
# MATERNO                                  1743 non-null object
# PATERNO                                  1744 non-null object
# NACIONALIDAD                             1743 non-null float64
# NOMBRE                                   1743 non-null object
# PREFERENCIA                              1743 non-null float64
# SEXO                                     1743 non-null float64
# CODIGO                                   1743 non-null float64
# ESTADO_DE_POSTULACION                    1743 non-null float64
# LUGAR_EN_LA_LISTA                        1743 non-null float64
# PUNTAJE_PONDERADO                        1743 non-null float64
# BEA                                      1743 non-null object
# LOCAL_EDUCACIONAL                        1743 non-null float64
# SITUACION_EGRESO_EDUCACIONAL             1743 non-null float64
# ROL_BASE_DATOS                           1743 non-null float64
# UNIDAD_EDUCATIVA                         1743 non-null float64
# COD_ENSENANZA                            1743 non-null float64
# GRUPO_DEPENDENCIA                        1743 non-null float64
# RAMA_EDUCACIONAL                         1743 non-null object
# CODIGO_PROVINCIA                         1743 non-null float64
# CODIGO_REGION                            1743 non-null float64
# AÑO_DE_EGRESO                            1743 non-null float64
# CODIGO_COMUNA                            1743 non-null float64
# PERCENTIL_NOTAS                          1743 non-null object
# PROMEDIO_DE_NOTAS                        1743 non-null float64
# PTJE_NEM                                 1743 non-null float64
# LENGUAJE_Y_COMUNICACION                  1743 non-null float64
# PTJE_RANKING                             1743 non-null float64
# HISTORIA_Y_CIENCIAS_SOCIALES             1743 non-null float64
# MATEMATICA                               1743 non-null float64
# CIENCIAS                                 1743 non-null float64
# MODULO_CIENCIAS                          1560 non-null object
# PERCENTIL_LM                             1743 non-null float64
# PROM_LM                                  1743 non-null float64
# FECHA_NACIMIENTO                         1743 non-null object
# CALLE                                    1743 non-null object
# INGRESO_BRUTO_FAMILIAR                   1743 non-null float64
# BLOCK                                    160 non-null object
# NUMERO                                   1743 non-null object
# DEPARTAMENTO                             203 non-null object
# COD_REGION                               1743 non-null float64
# VILLA/POBLACION                          1333 non-null object
# COD_COMUNA                               1743 non-null float64
# COD_PROVINCIA                            1743 non-null float64
# NOMBRE_COMUNA                            1743 non-null object
# NOMBRE_PROVINCIA                         1743 non-null object
# CIUDAD                                   1743 non-null object
# CELULAR                                  1743 non-null object
# NUMERO_TELEFONO                          1743 non-null object
# EMAIL                                    1743 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    1743 non-null object
# NRO_TARJETA_DE_MATRICULA                 1743 non-null float64
# Id                                       1746 non-null int64
# POND_AÑO_ACAD                            1743 non-null float64
# dtypes: float64(33), int64(1), object(22)
# memory usage: 764.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1746 entries, 0 to 1745
# Data columns (total 20 columns):
# NUMERO_DOCUMENTO          1744 non-null object
# TIPO_DE_IDENTIFICACION    1744 non-null object
# AÑO_PROCESO               1744 non-null object
# MATERNO                   1743 non-null object
# PATERNO                   1744 non-null object
# NOMBRES                   1743 non-null object
# CODIGO_CARRERA            1743 non-null object
# PREFERENCIA               1743 non-null object
# NOMBRE_CARRERA            1743 non-null object
# SIGLA_UNIVERSIDAD         1743 non-null object
# VACANTES                  1743 non-null object
# NOMBRE_UNIVERSIDAD        1743 non-null object
# PUNTAJE                   1743 non-null object
# SITUACION                 1743 non-null object
# BEA                       1743 non-null object
# LUGAR                     1743 non-null object
# EMAIL                     1743 non-null object
# FECHA_NACIMIENTO          1743 non-null object
# Id                        1746 non-null int64
# POND_AÑO_ACAD             1743 non-null object
# dtypes: int64(1), object(19)
# memory usage: 272.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5745 entries, 0 to 5744
# Data columns (total 28 columns):
# Id                                     5745 non-null int64
# AÑO_PROCESO                            5742 non-null float64
# LOCAL_EDUCATIVA                        5743 non-null float64
# UNIDAD_EDUCATIVA                       5742 non-null float64
# NOMBRE_OFICIAL                         5743 non-null object
# CODIGO_REGION                          5742 non-null object
# CODIGO_PROVINCIA                       5742 non-null object
# CODIGO_COMUNA                          5742 non-null float64
# CODIGO_POSTAL                          5742 non-null object
# FONO_PRINCIPAL                         5742 non-null object
# FAX                                    5742 non-null object
# EMAIL                                  4583 non-null object
# DIRECCION                              5742 non-null object
# DEPENDENCIA                            5742 non-null object
# RAMA_EDUCACIONAL                       5742 non-null object
# REGIMEN                                5742 non-null object
# GRUPO_DEPENDENCIA                      5742 non-null object
# MATRICULA_PENULTIMO_CURSO_MASCULINO    5742 non-null object
# MATRICULA_PENULTIMO_CURSO_FEMENINO     5742 non-null object
# MATRICULA_PENULTIMO_CURSO_TOTAL        5742 non-null object
# MATRICULA_ULTIMO_CURSO_MASCULINO       5742 non-null object
# MATRICULA_ULTIMO_CURSO_FEMENINO        5742 non-null object
# MATRICULA_ULTIMO_CURSO_TOTAL           5742 non-null object
# NOMBRE_DIRECTOR                        5645 non-null object
# NOMBRE_ORIENTADOR                      4568 non-null object
# COD_ENSENANZA                          5742 non-null object
# NOMBRE_RELACIONADOR                    4581 non-null object
# ROL_BASE_DATOS                         5742 non-null object
# dtypes: float64(4), int64(1), object(23)
# memory usage: 1.2+ MB
# None

# %%
# Paso 6: Quitar valores nulos conocidos
p18.replace_null_values(null_dict)

# %%
# Paso 7: Cargar en sql con tipos de datos, si se asignan
p18.to_sql(engine)
# Out:
# 00:18:11.88

# %%
# Opcional
p18.tables_to_sql(engine, ['e'], type_list=True, if_exists='replace')
# Out:
# 00:00:47.67

# %% [markdown]
# ## 2.2 PSU 2017

# %%
# Creación de la instancia
file_path = r"C:\Users\fpalomer\Documents\PSU\PSU_2017.mdb"
p17 = PrepPsuAccess(file_path)

# %%
# Paso 1: Limpiar nombre de las columnas
p17.clean_columns_name()
# Out:
# En p17_a no hubo cambios
# En p17_b no hubo cambios
# En p17_c no hubo cambios
# En p17_e_bea no hubo cambios
# En p17_e_edt no hubo cambios
# En p17_e_pace no hubo cambios
# En p17_e_psu no hubo cambios
# En p17_e_sidd no hubo cambios
# En p17_e_sieg no hubo cambios
# En p17_e_sipee no hubo cambios
# En p17_g no hubo cambios
# En p17_g_bea no hubo cambios
# En p17_g_pace no hubo cambios

# %%
# Paso 2: Homogeneizar nombre de columnas
p17.rename_columns(colname_dict)

# %%
# Paso 3: Transformaciones varias
p17.transform_col(transformer_dict)

# %%
# Paso 4: Remover valores no númericos en columnas númericas
p17.remove_numeric_dirtydata(dtypes_dict)

# %%
# Paso 5: cambio de datos
p17.change_column_dtype(dtypes_dict)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1370 entries, 0 to 1369
# Data columns (total 59 columns):
# NUMERO_DOCUMENTO                         1370 non-null object
# TIPO_DE_IDENTIFICACION                   1370 non-null object
# AÑO_PROCESO                              1370 non-null int64
# MATERNO                                  1370 non-null object
# PATERNO                                  1370 non-null object
# NACIONALIDAD                             1370 non-null int64
# NOMBRE                                   1370 non-null object
# PREFERENCIA                              1370 non-null int64
# SEXO                                     1370 non-null int64
# CODIGO                                   1370 non-null int64
# ESTADO_DE_POSTULACION                    1370 non-null int64
# LUGAR_EN_LA_LISTA                        1370 non-null int64
# PUNTAJE_PONDERADO                        1370 non-null float64
# BEA                                      1370 non-null object
# LOCAL_EDUCACIONAL                        1370 non-null int64
# SITUACION_EGRESO_EDUCACIONAL             1370 non-null int64
# ROL_BASE_DATOS                           1370 non-null int64
# UNIDAD_EDUCATIVA                         1370 non-null int64
# COD_ENSENANZA                            1370 non-null int64
# GRUPO_DEPENDENCIA                        1370 non-null int64
# RAMA_EDUCACIONAL                         1370 non-null object
# CODIGO_PROVINCIA                         1370 non-null int64
# CODIGO_REGION                            1370 non-null int64
# AÑO_DE_EGRESO                            1370 non-null int64
# CODIGO_COMUNA                            1370 non-null int64
# HABILITA_PEDAGOGIA                       1370 non-null object
# PROMEDIO_DE_NOTAS                        1370 non-null float64
# PTJE_NEM                                 1370 non-null int64
# LENGUAJE_Y_COMUNICACION                  1370 non-null int64
# PTJE_RANKING                             1370 non-null int64
# HISTORIA_Y_CIENCIAS_SOCIALES             1370 non-null int64
# MATEMATICA                               1370 non-null int64
# CIENCIAS                                 1370 non-null int64
# MODULO_CIENCIAS                          1221 non-null object
# PERCENTIL_LM                             1370 non-null float64
# PROM_LM                                  1370 non-null float64
# FECHA_NACIMIENTO                         1370 non-null object
# COBERTURA_SALUD                          1370 non-null object
# INGRESO_BRUTO_FAMILIAR                   1370 non-null int64
# RUT_MADRE                                1370 non-null object
# RUT_PADRE                                1370 non-null object
# CALLE                                    1370 non-null object
# BLOCK                                    129 non-null object
# NUMERO                                   1370 non-null object
# DEPARTAMENTO                             158 non-null object
# COD_REGION                               1370 non-null int64
# VILLA/POBLACION                          1043 non-null object
# COD_COMUNA                               1370 non-null int64
# COD_PROVINCIA                            1370 non-null int64
# NOMBRE_COMUNA                            1370 non-null object
# NOMBRE_PROVINCIA                         1370 non-null object
# CIUDAD                                   1370 non-null object
# NUMERO_DE_CELULAR                        1370 non-null object
# NUMERO_DE_TELEFONO                       1370 non-null object
# EMAIL                                    1370 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    1370 non-null object
# NRO_TARJETA_DE_MATRICULA                 1370 non-null int64
# Id                                       1370 non-null int64
# POND_AÑO_ACAD                            1370 non-null int64
# dtypes: float64(4), int64(30), object(25)
# memory usage: 631.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 59 columns):
# NUMERO_DOCUMENTO                         14 non-null object
# TIPO_DE_IDENTIFICACION                   14 non-null object
# AÑO_PROCESO                              14 non-null int64
# MATERNO                                  14 non-null object
# PATERNO                                  14 non-null object
# NACIONALIDAD                             14 non-null int64
# NOMBRE                                   14 non-null object
# PREFERENCIA                              14 non-null int64
# SEXO                                     14 non-null int64
# CODIGO                                   14 non-null int64
# ESTADO_DE_POSTULACION                    14 non-null int64
# LUGAR_EN_LA_LISTA                        14 non-null int64
# PUNTAJE_PONDERADO                        14 non-null float64
# BEA                                      7 non-null object
# LOCAL_EDUCACIONAL                        14 non-null int64
# SITUACION_EGRESO_EDUCACIONAL             14 non-null int64
# ROL_BASE_DATOS                           14 non-null int64
# UNIDAD_EDUCATIVA                         14 non-null int64
# COD_ENSENANZA                            14 non-null int64
# GRUPO_DEPENDENCIA                        14 non-null int64
# RAMA_EDUCACIONAL                         14 non-null object
# CODIGO_PROVINCIA                         14 non-null int64
# CODIGO_REGION                            14 non-null int64
# AÑO_DE_EGRESO                            14 non-null int64
# CODIGO_COMUNA                            14 non-null int64
# HABILITA_PEDAGOGIA                       14 non-null object
# PROMEDIO_DE_NOTAS                        14 non-null float64
# PTJE_NEM                                 14 non-null int64
# LENGUAJE_Y_COMUNICACION                  14 non-null int64
# PTJE_RANKING                             14 non-null int64
# HISTORIA_Y_CIENCIAS_SOCIALES             14 non-null int64
# MATEMATICA                               14 non-null int64
# CIENCIAS                                 14 non-null int64
# MODULO_CIENCIAS                          12 non-null object
# PERCENTIL_LM                             14 non-null float64
# PROM_LM                                  14 non-null float64
# FECHA_NACIMIENTO                         14 non-null object
# COBERTURA_SALUD                          14 non-null object
# INGRESO_BRUTO_FAMILIAR                   14 non-null int64
# RUT_MADRE                                14 non-null object
# RUT_PADRE                                14 non-null object
# CALLE                                    14 non-null object
# BLOCK                                    1 non-null object
# NUMERO                                   14 non-null object
# DEPARTAMENTO                             1 non-null object
# COD_REGION                               14 non-null int64
# VILLA/POBLACION                          11 non-null object
# COD_COMUNA                               14 non-null int64
# COD_PROVINCIA                            14 non-null int64
# NOMBRE_COMUNA                            14 non-null object
# NOMBRE_PROVINCIA                         14 non-null object
# CIUDAD                                   14 non-null object
# NUMERO_DE_CELULAR                        14 non-null object
# NUMERO_DE_TELEFONO                       14 non-null object
# EMAIL                                    14 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    14 non-null object
# NRO_TARJETA_DE_MATRICULA                 14 non-null int64
# Id                                       14 non-null int64
# POND_AÑO_ACAD                            14 non-null int64
# dtypes: float64(4), int64(30), object(25)
# memory usage: 6.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 57 columns):
# Id                                       696 non-null int64
# TIPO_DE_IDENTIFICACION                   696 non-null object
# NUMERO_DOCUMENTO                         696 non-null object
# AÑO_PROCESO                              696 non-null int64
# PATERNO                                  696 non-null object
# MATERNO                                  696 non-null object
# NOMBRE                                   696 non-null object
# NACIONALIDAD                             696 non-null int64
# SEXO                                     696 non-null int64
# PREFERENCIA                              696 non-null int64
# CODIGO                                   696 non-null int64
# ESTADO_DE_POSTULACION                    696 non-null int64
# PUNTAJE_PONDERADO                        696 non-null float64
# LUGAR_EN_LA_LISTA                        696 non-null int64
# LOCAL_EDUCACIONAL                        696 non-null int64
# PASE                                     696 non-null object
# SITUACION_EGRESO_EDUCACIONAL             696 non-null int64
# UNIDAD_EDUCATIVA                         696 non-null int64
# ROL_BASE_DATOS                           696 non-null int64
# RAMA_EDUCACIONAL                         696 non-null object
# GRUPO_DEPENDENCIA                        696 non-null int64
# CODIGO_REGION                            696 non-null int64
# CODIGO_PROVINCIA                         696 non-null int64
# CODIGO_COMUNA                            696 non-null int64
# AÑO_DE_EGRESO                            696 non-null int64
# PROMEDIO_DE_NOTAS                        696 non-null float64
# HABILITA_PEDAGOGIA                       696 non-null object
# LENGUAJE_Y_COMUNICACION                  696 non-null int64
# PTJE_NEM                                 696 non-null int64
# PTJE_RANKING                             696 non-null int64
# MATEMATICA                               696 non-null int64
# HISTORIA_Y_CIENCIAS_SOCIALES             696 non-null int64
# CIENCIAS                                 696 non-null int64
# MODULO_CIENCIAS                          571 non-null object
# PROM_LM                                  696 non-null float64
# PERCENTIL_LM                             696 non-null float64
# COBERTURA_SALUD                          696 non-null object
# FECHA_NACIMIENTO                         696 non-null object
# INGRESO_BRUTO_FAMILIAR                   696 non-null int64
# RUT_PADRE                                696 non-null object
# RUT_MADRE                                696 non-null object
# BLOCK                                    53 non-null object
# CALLE                                    696 non-null object
# NUMERO                                   696 non-null object
# COD_REGION                               696 non-null int64
# DEPARTAMENTO                             63 non-null object
# VILLA/POBLACION                          508 non-null object
# COD_PROVINCIA                            696 non-null int64
# COD_COMUNA                               696 non-null int64
# NOMBRE_PROVINCIA                         696 non-null object
# NOMBRE_COMUNA                            696 non-null object
# CIUDAD                                   696 non-null object
# NUMERO_TELEFONO                          696 non-null object
# NUMERO_CELULAR                           696 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    696 non-null object
# EMAIL                                    695 non-null object
# NRO_TARJETA_DE_MATRICULA                 696 non-null int64
# dtypes: float64(4), int64(28), object(25)
# memory usage: 310.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17910 entries, 0 to 17909
# Data columns (total 59 columns):
# NUMERO_DOCUMENTO                         17910 non-null object
# TIPO_DE_IDENTIFICACION                   17910 non-null object
# AÑO_PROCESO                              17910 non-null int64
# MATERNO                                  17910 non-null object
# PATERNO                                  17910 non-null object
# NACIONALIDAD                             17910 non-null int64
# NOMBRE                                   17910 non-null object
# PREFERENCIA                              17910 non-null int64
# SEXO                                     17910 non-null int64
# CODIGO                                   17910 non-null int64
# ESTADO_DE_POSTULACION                    17910 non-null int64
# LUGAR_EN_LA_LISTA                        17910 non-null int64
# PUNTAJE_PONDERADO                        17910 non-null float64
# BEA                                      1925 non-null object
# LOCAL_EDUCACIONAL                        17910 non-null int64
# SITUACION_EGRESO_EDUCACIONAL             17910 non-null int64
# ROL_BASE_DATOS                           17910 non-null int64
# UNIDAD_EDUCATIVA                         17910 non-null int64
# COD_ENSENANZA                            17910 non-null int64
# GRUPO_DEPENDENCIA                        17910 non-null int64
# RAMA_EDUCACIONAL                         17906 non-null object
# CODIGO_PROVINCIA                         17910 non-null int64
# CODIGO_REGION                            17910 non-null int64
# AÑO_DE_EGRESO                            17910 non-null int64
# CODIGO_COMUNA                            17910 non-null int64
# HABILITA_PEDAGOGIA                       17910 non-null object
# PROMEDIO_DE_NOTAS                        17910 non-null float64
# PTJE_NEM                                 17910 non-null int64
# LENGUAJE_Y_COMUNICACION                  17910 non-null int64
# PTJE_RANKING                             17910 non-null int64
# HISTORIA_Y_CIENCIAS_SOCIALES             17910 non-null int64
# MATEMATICA                               17910 non-null int64
# CIENCIAS                                 17910 non-null int64
# MODULO_CIENCIAS                          13422 non-null object
# PERCENTIL_LM                             17910 non-null float64
# PROM_LM                                  17910 non-null float64
# FECHA_NACIMIENTO                         17910 non-null object
# COBERTURA_SALUD                          17910 non-null object
# INGRESO_BRUTO_FAMILIAR                   17910 non-null int64
# RUT_MADRE                                17910 non-null object
# RUT_PADRE                                17910 non-null object
# CALLE                                    17910 non-null object
# BLOCK                                    1733 non-null object
# NUMERO                                   17910 non-null object
# DEPARTAMENTO                             3447 non-null object
# COD_REGION                               17910 non-null int64
# VILLA/POBLACION                          10702 non-null object
# COD_COMUNA                               17910 non-null int64
# COD_PROVINCIA                            17910 non-null int64
# NOMBRE_COMUNA                            17910 non-null object
# NOMBRE_PROVINCIA                         17910 non-null object
# CIUDAD                                   17910 non-null object
# NUMERO_DE_CELULAR                        17910 non-null object
# NUMERO_DE_TELEFONO                       17910 non-null object
# EMAIL                                    17901 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    17910 non-null object
# NRO_TARJETA_DE_MATRICULA                 17910 non-null int64
# Id                                       17910 non-null int64
# POND_AÑO_ACAD                            17910 non-null int64
# dtypes: float64(4), int64(30), object(25)
# memory usage: 8.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 59 columns):
# NUMERO_DOCUMENTO                         92 non-null object
# TIPO_DE_IDENTIFICACION                   92 non-null object
# AÑO_PROCESO                              92 non-null int64
# MATERNO                                  92 non-null object
# PATERNO                                  92 non-null object
# NACIONALIDAD                             92 non-null int64
# NOMBRE                                   92 non-null object
# PREFERENCIA                              92 non-null int64
# SEXO                                     92 non-null int64
# CODIGO                                   92 non-null int64
# ESTADO_DE_POSTULACION                    92 non-null int64
# LUGAR_EN_LA_LISTA                        92 non-null int64
# PUNTAJE_PONDERADO                        92 non-null float64
# BEA                                      1 non-null object
# LOCAL_EDUCACIONAL                        92 non-null int64
# SITUACION_EGRESO_EDUCACIONAL             92 non-null int64
# ROL_BASE_DATOS                           92 non-null int64
# UNIDAD_EDUCATIVA                         92 non-null int64
# COD_ENSENANZA                            92 non-null int64
# GRUPO_DEPENDENCIA                        92 non-null int64
# RAMA_EDUCACIONAL                         92 non-null object
# CODIGO_PROVINCIA                         92 non-null int64
# CODIGO_REGION                            92 non-null int64
# AÑO_DE_EGRESO                            92 non-null int64
# CODIGO_COMUNA                            92 non-null int64
# HABILITA_PEDAGOGIA                       92 non-null object
# PROMEDIO_DE_NOTAS                        92 non-null float64
# PTJE_NEM                                 92 non-null int64
# LENGUAJE_Y_COMUNICACION                  92 non-null int64
# PTJE_RANKING                             92 non-null int64
# HISTORIA_Y_CIENCIAS_SOCIALES             92 non-null int64
# MATEMATICA                               92 non-null int64
# CIENCIAS                                 92 non-null int64
# MODULO_CIENCIAS                          71 non-null object
# PERCENTIL_LM                             92 non-null float64
# PROM_LM                                  92 non-null float64
# FECHA_NACIMIENTO                         92 non-null object
# COBERTURA_SALUD                          92 non-null object
# INGRESO_BRUTO_FAMILIAR                   92 non-null int64
# RUT_MADRE                                92 non-null object
# RUT_PADRE                                92 non-null object
# CALLE                                    92 non-null object
# BLOCK                                    12 non-null object
# NUMERO                                   92 non-null object
# DEPARTAMENTO                             23 non-null object
# COD_REGION                               92 non-null int64
# VILLA/POBLACION                          36 non-null object
# COD_COMUNA                               92 non-null int64
# COD_PROVINCIA                            92 non-null int64
# NOMBRE_COMUNA                            92 non-null object
# NOMBRE_PROVINCIA                         92 non-null object
# CIUDAD                                   92 non-null object
# NUMERO_DE_CELULAR                        92 non-null object
# NUMERO_DE_TELEFONO                       92 non-null object
# EMAIL                                    92 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    92 non-null object
# NRO_TARJETA_DE_MATRICULA                 92 non-null int64
# Id                                       92 non-null int64
# POND_AÑO_ACAD                            92 non-null int64
# dtypes: float64(4), int64(30), object(25)
# memory usage: 42.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 59 columns):
# NUMERO_DOCUMENTO                         321 non-null object
# TIPO_DE_IDENTIFICACION                   321 non-null object
# AÑO_PROCESO                              321 non-null int64
# MATERNO                                  321 non-null object
# PATERNO                                  321 non-null object
# NACIONALIDAD                             321 non-null int64
# NOMBRE                                   321 non-null object
# PREFERENCIA                              321 non-null int64
# SEXO                                     321 non-null int64
# CODIGO                                   321 non-null int64
# ESTADO_DE_POSTULACION                    321 non-null int64
# LUGAR_EN_LA_LISTA                        321 non-null int64
# PUNTAJE_PONDERADO                        321 non-null float64
# BEA                                      33 non-null object
# LOCAL_EDUCACIONAL                        321 non-null int64
# SITUACION_EGRESO_EDUCACIONAL             321 non-null int64
# ROL_BASE_DATOS                           321 non-null int64
# UNIDAD_EDUCATIVA                         321 non-null int64
# COD_ENSENANZA                            321 non-null int64
# GRUPO_DEPENDENCIA                        321 non-null int64
# RAMA_EDUCACIONAL                         321 non-null object
# CODIGO_PROVINCIA                         321 non-null int64
# CODIGO_REGION                            321 non-null int64
# AÑO_DE_EGRESO                            321 non-null int64
# CODIGO_COMUNA                            321 non-null int64
# HABILITA_PEDAGOGIA                       321 non-null object
# PROMEDIO_DE_NOTAS                        321 non-null float64
# PTJE_NEM                                 321 non-null int64
# LENGUAJE_Y_COMUNICACION                  321 non-null int64
# PTJE_RANKING                             321 non-null int64
# HISTORIA_Y_CIENCIAS_SOCIALES             321 non-null int64
# MATEMATICA                               321 non-null int64
# CIENCIAS                                 321 non-null int64
# MODULO_CIENCIAS                          321 non-null object
# PERCENTIL_LM                             321 non-null float64
# PROM_LM                                  321 non-null float64
# FECHA_NACIMIENTO                         321 non-null object
# COBERTURA_SALUD                          321 non-null object
# INGRESO_BRUTO_FAMILIAR                   321 non-null int64
# RUT_MADRE                                321 non-null object
# RUT_PADRE                                321 non-null object
# CALLE                                    321 non-null object
# BLOCK                                    39 non-null object
# NUMERO                                   321 non-null object
# DEPARTAMENTO                             70 non-null object
# COD_REGION                               321 non-null int64
# VILLA/POBLACION                          186 non-null object
# COD_COMUNA                               321 non-null int64
# COD_PROVINCIA                            321 non-null int64
# NOMBRE_COMUNA                            321 non-null object
# NOMBRE_PROVINCIA                         321 non-null object
# CIUDAD                                   321 non-null object
# NUMERO_DE_CELULAR                        321 non-null object
# NUMERO_DE_TELEFONO                       321 non-null object
# EMAIL                                    321 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    321 non-null object
# NRO_TARJETA_DE_MATRICULA                 321 non-null int64
# Id                                       321 non-null int64
# POND_AÑO_ACAD                            321 non-null int64
# dtypes: float64(4), int64(30), object(25)
# memory usage: 148.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104 entries, 0 to 1103
# Data columns (total 59 columns):
# NUMERO_DOCUMENTO                         1104 non-null object
# TIPO_DE_IDENTIFICACION                   1104 non-null object
# AÑO_PROCESO                              1104 non-null int64
# MATERNO                                  1104 non-null object
# PATERNO                                  1104 non-null object
# NACIONALIDAD                             1104 non-null int64
# NOMBRE                                   1104 non-null object
# PREFERENCIA                              1104 non-null int64
# SEXO                                     1104 non-null int64
# CODIGO                                   1104 non-null int64
# ESTADO_DE_POSTULACION                    1104 non-null int64
# LUGAR_EN_LA_LISTA                        1104 non-null int64
# PUNTAJE_PONDERADO                        1104 non-null float64
# BEA                                      262 non-null object
# LOCAL_EDUCACIONAL                        1104 non-null int64
# SITUACION_EGRESO_EDUCACIONAL             1104 non-null int64
# ROL_BASE_DATOS                           1104 non-null int64
# UNIDAD_EDUCATIVA                         1104 non-null int64
# COD_ENSENANZA                            1104 non-null int64
# GRUPO_DEPENDENCIA                        1104 non-null int64
# RAMA_EDUCACIONAL                         1104 non-null object
# CODIGO_PROVINCIA                         1104 non-null int64
# CODIGO_REGION                            1104 non-null int64
# AÑO_DE_EGRESO                            1104 non-null int64
# CODIGO_COMUNA                            1104 non-null int64
# HABILITA_PEDAGOGIA                       1104 non-null object
# PROMEDIO_DE_NOTAS                        1104 non-null float64
# PTJE_NEM                                 1104 non-null int64
# LENGUAJE_Y_COMUNICACION                  1104 non-null int64
# PTJE_RANKING                             1104 non-null int64
# HISTORIA_Y_CIENCIAS_SOCIALES             1104 non-null int64
# MATEMATICA                               1104 non-null int64
# CIENCIAS                                 1104 non-null int64
# MODULO_CIENCIAS                          954 non-null object
# PERCENTIL_LM                             1104 non-null float64
# PROM_LM                                  1104 non-null float64
# FECHA_NACIMIENTO                         1104 non-null object
# COBERTURA_SALUD                          1104 non-null object
# INGRESO_BRUTO_FAMILIAR                   1104 non-null int64
# RUT_MADRE                                1104 non-null object
# RUT_PADRE                                1104 non-null object
# CALLE                                    1104 non-null object
# BLOCK                                    94 non-null object
# NUMERO                                   1104 non-null object
# DEPARTAMENTO                             137 non-null object
# COD_REGION                               1104 non-null int64
# VILLA/POBLACION                          831 non-null object
# COD_COMUNA                               1104 non-null int64
# COD_PROVINCIA                            1104 non-null int64
# NOMBRE_COMUNA                            1104 non-null object
# NOMBRE_PROVINCIA                         1104 non-null object
# CIUDAD                                   1104 non-null object
# NUMERO_DE_CELULAR                        1104 non-null object
# NUMERO_DE_TELEFONO                       1104 non-null object
# EMAIL                                    1104 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    1104 non-null object
# NRO_TARJETA_DE_MATRICULA                 1104 non-null int64
# Id                                       1104 non-null int64
# POND_AÑO_ACAD                            1104 non-null int64
# dtypes: float64(4), int64(30), object(25)
# memory usage: 509.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271913 entries, 0 to 271912
# Data columns (total 35 columns):
# Id                                            271913 non-null int64
# TIPO_DE_IDENTIFICACION                        271913 non-null object
# NUMERO_DOCUMENTO                              271913 non-null object
# AÑO_DOCUMENTO                                 271913 non-null object
# SITUACION_EGRESO_EDUCACIONAL                  271913 non-null object
# LOCAL_EDUCACIONAL                             271913 non-null int64
# UNIDAD_EDUCATIVA                              271913 non-null int64
# ROL_BASE_DATOS                                271913 non-null object
# COD_ENSENANZA                                 271913 non-null object
# RAMA_EDUCACIONAL                              271743 non-null object
# GRUPO_DEPENDENCIA                             271913 non-null object
# CODIGO_REGION                                 271913 non-null int64
# CODIGO_PROVINCIA                              271913 non-null int64
# CODIGO_COMUNA                                 271913 non-null int64
# AÑO_EGRESO_ENSEÑANZA_MEDIA                    271913 non-null object
# BEA                                           12783 non-null object
# HABILITA_PEDAGOGIA_(SI_NO)                    271913 non-null object
# PACE                                          17384 non-null object
# PROMEDIO_NOTAS                                271913 non-null float64
# PTJE_LENGUAJE_Y_COMUNICACION_ACTUAL           271913 non-null int64
# PTJE_NEM                                      271913 non-null int64
# PTJE_RANKING                                  271913 non-null int64
# PTJE_MATEMATICA_ACTUAL                        271913 non-null int64
# PTJE_HISTORIA_Y_CIENCIAS_SOCIALES_ACTUAL      271913 non-null int64
# PTJE_CIENCIAS_ACTUAL                          271913 non-null int64
# MODULO_CIENCIAS_ACTUAL                        163945 non-null object
# PROM_LM_ACTUAL                                271913 non-null float64
# PERCENTIL_LM_ACTUAL                           271913 non-null object
# PTJE_HISTORIA_Y_CIENCIAS_SOCIALES_ANTERIOR    271913 non-null object
# PTJE_LENGUAJE_Y_COMUNICACION_ANTERIOR         271913 non-null object
# PTJE_MATEMATICA_ANTERIOR                      271913 non-null object
# PTJE_CIENCIAS_ANTERIOR                        271913 non-null object
# MODULO_CIENCIAS_ANTERIOR                      28661 non-null object
# PROM_LM_ANTERIOR                              271913 non-null float64
# PERCENTIL_LM_ANTERIOR                         271913 non-null object
# dtypes: float64(3), int64(12), object(20)
# memory usage: 72.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299910 entries, 0 to 299909
# Data columns (total 57 columns):
# NUMERO_DOCUMENTO                         299910 non-null object
# TIPO_DE_IDENTIFICACION                   299910 non-null object
# AÑO_PROCESO                              299910 non-null object
# MATERNO                                  299910 non-null object
# PATERNO                                  299910 non-null object
# NACIONALIDAD                             299910 non-null object
# NOMBRES                                  299910 non-null object
# LOCAL_EDUCATIVA                          299910 non-null object
# SEXO                                     299910 non-null object
# ROL_BASE_DATOS                           299910 non-null object
# UNIDAD_EDUCATIVA                         299910 non-null object
# COD_ENSENANZA                            299910 non-null object
# CODIGO_PROVINCIA                         299910 non-null object
# CODIGO_REGION                            299910 non-null object
# AÑO_EGRESO_ENSEÑANZA_MEDIA               299910 non-null object
# CODIGO_COMUNA                            299910 non-null object
# ESTADO_CIVIL                             299910 non-null object
# FECHA_NACIMIENTO                         299910 non-null object
# HORARIO_TRABAJO                          299910 non-null object
# TIENE_TRABAJO_REMUNERADO                 299910 non-null object
# DE_PROSEGUIR_ESTUDIOS                    299910 non-null object
# HORAS_QUE_DEDICA_TRABAJO                 299910 non-null object
# CUANTOS_TRABAJAN_GRUPO_FAMILIAR          299910 non-null object
# GRUPO_FAMILIAR                           299910 non-null object
# QUIEN_ES_EL_JEFE_DE_FAMILIA              299910 non-null object
# CUANTOS_ESTUDIAN_GRUPO_FAMILIAR          299910 non-null object
# QUIEN_FINANCIARA_ESTUDIOS                299910 non-null object
# COBERTURA_SALUD                          299910 non-null object
# INGRESO_BRUTO_FAMILIAR                   299910 non-null int64
# ¿VIVEN_SUS_PADRES?                       299910 non-null object
# EDUCACION_DE_LOS_PADRES                  299910 non-null object
# SITUACION_OCUPACIONAL                    299910 non-null object
# OCUPACION_PRINCIPAL                      299910 non-null object
# TIPO_ORGANISMO_TRABAJAN                  299910 non-null object
# RAMA_ACTIVIDAD                           299910 non-null object
# RUT_MADRE                                299910 non-null object
# RUT_PADRE                                299910 non-null object
# CALLE                                    299910 non-null object
# BLOCK                                    27426 non-null object
# NUMERO                                   299910 non-null object
# DEPARTAMENTO                             38851 non-null object
# COD_REGION                               299910 non-null object
# VILLA/POBLACION                          222266 non-null object
# COD_COMUNA                               299910 non-null object
# COD_PROVINCIA                            299910 non-null object
# NOMBRE_COMUNA                            299910 non-null object
# NOMBRE_PROVINCIA                         299910 non-null object
# CIUDAD                                   299910 non-null object
# NUMERO_CELULAR                           299910 non-null object
# NUMERO_TELEFONO                          299910 non-null object
# EMAIL                                    299843 non-null object
# BEA                                      13152 non-null object
# NRO_TARJETA_MATRICULA                    299910 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    299910 non-null object
# PACE                                     20183 non-null object
# Id                                       299910 non-null int64
# RINDE_PROCESO                            299910 non-null object
# dtypes: int64(2), object(55)
# memory usage: 130.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1370 entries, 0 to 1369
# Data columns (total 59 columns):
# NUMERO_DOCUMENTO                         1370 non-null object
# TIPO_DE_IDENTIFICACION                   1370 non-null object
# AÑO_PROCESO                              1370 non-null int64
# MATERNO                                  1370 non-null object
# PATERNO                                  1370 non-null object
# NACIONALIDAD                             1370 non-null int64
# NOMBRE                                   1370 non-null object
# PREFERENCIA                              1370 non-null int64
# SEXO                                     1370 non-null int64
# CODIGO                                   1370 non-null int64
# ESTADO_DE_POSTULACION                    1370 non-null int64
# LUGAR_EN_LA_LISTA                        1370 non-null int64
# PUNTAJE_PONDERADO                        1370 non-null float64
# BEA                                      1370 non-null object
# LOCAL_EDUCACIONAL                        1370 non-null int64
# SITUACION_EGRESO_EDUCACIONAL             1370 non-null int64
# ROL_BASE_DATOS                           1370 non-null int64
# UNIDAD_EDUCATIVA                         1370 non-null int64
# COD_ENSENANZA                            1370 non-null int64
# GRUPO_DEPENDENCIA                        1370 non-null int64
# RAMA_EDUCACIONAL                         1370 non-null object
# CODIGO_PROVINCIA                         1370 non-null int64
# CODIGO_REGION                            1370 non-null int64
# AÑO_DE_EGRESO                            1370 non-null int64
# CODIGO_COMUNA                            1370 non-null int64
# HABILITA_PEDAGOGIA                       1370 non-null object
# PROMEDIO_DE_NOTAS                        1370 non-null float64
# PTJE_NEM                                 1370 non-null int64
# LENGUAJE_Y_COMUNICACION                  1370 non-null int64
# PTJE_RANKING                             1370 non-null int64
# HISTORIA_Y_CIENCIAS_SOCIALES             1370 non-null int64
# MATEMATICA                               1370 non-null int64
# CIENCIAS                                 1370 non-null int64
# MODULO_CIENCIAS                          1221 non-null object
# PERCENTIL_LM                             1370 non-null float64
# PROM_LM                                  1370 non-null float64
# FECHA_NACIMIENTO                         1370 non-null object
# COBERTURA_SALUD                          1370 non-null object
# INGRESO_BRUTO_FAMILIAR                   1370 non-null int64
# RUT_MADRE                                1370 non-null object
# RUT_PADRE                                1370 non-null object
# CALLE                                    1370 non-null object
# BLOCK                                    129 non-null object
# NUMERO                                   1370 non-null object
# DEPARTAMENTO                             158 non-null object
# COD_REGION                               1370 non-null int64
# VILLA/POBLACION                          1043 non-null object
# COD_COMUNA                               1370 non-null int64
# COD_PROVINCIA                            1370 non-null int64
# NOMBRE_COMUNA                            1370 non-null object
# NOMBRE_PROVINCIA                         1370 non-null object
# CIUDAD                                   1370 non-null object
# NUMERO_DE_CELULAR                        1370 non-null object
# NUMERO_DE_TELEFONO                       1370 non-null object
# EMAIL                                    1370 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    1370 non-null object
# NRO_TARJETA_DE_MATRICULA                 1370 non-null int64
# Id                                       1370 non-null int64
# POND_AÑO_ACAD                            1370 non-null int64
# dtypes: float64(4), int64(30), object(25)
# memory usage: 631.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1370 entries, 0 to 1369
# Data columns (total 20 columns):
# NUMERO_DOCUMENTO          1370 non-null object
# TIPO_DE_IDENTIFICACION    1370 non-null object
# AÑO_PROCESO               1370 non-null object
# MATERNO                   1370 non-null object
# PATERNO                   1370 non-null object
# NOMBRES                   1370 non-null object
# CODIGO_CARRERA            1370 non-null object
# PREFERENCIA               1370 non-null object
# NOMBRE_CARRERA            1370 non-null object
# SIGLA_UNIVERSIDAD         1370 non-null object
# VACANTES                  1370 non-null object
# NOMBRE_UNIVERSIDAD        1370 non-null object
# PUNTAJE                   1370 non-null object
# SITUACION                 1370 non-null object
# BEA                       1370 non-null object
# LUGAR                     1370 non-null object
# EMAIL                     1370 non-null object
# FECHA_NACIMIENTO          1370 non-null object
# Id                        1370 non-null int64
# POND_AÑO_ACAD             1370 non-null object
# dtypes: int64(1), object(19)
# memory usage: 214.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13832 entries, 0 to 13831
# Data columns (total 28 columns):
# Id                                     13832 non-null int64
# AÑO_PROCESO                            13832 non-null int64
# LOCAL_EDUCATIVA                        13832 non-null int64
# UNIDAD_EDUCATIVA                       13832 non-null int64
# NOMBRE_OFICIAL                         13832 non-null object
# CODIGO_REGION                          13832 non-null object
# CODIGO_PROVINCIA                       13832 non-null object
# CODIGO_COMUNA                          13832 non-null int64
# CODIGO_POSTAL                          13832 non-null object
# FONO_PRINCIPAL                         13832 non-null object
# FAX                                    13832 non-null object
# EMAIL                                  4746 non-null object
# DIRECCION                              13832 non-null object
# DEPENDENCIA                            13832 non-null object
# RAMA_EDUCACIONAL                       13832 non-null object
# REGIMEN                                13832 non-null object
# GRUPO_DEPENDENCIA                      13832 non-null object
# MATRICULA_PENULTIMO_CURSO_MASCULINO    13832 non-null object
# MATRICULA_PENULTIMO_CURSO_FEMENINO     13832 non-null object
# MATRICULA_PENULTIMO_CURSO_TOTAL        13832 non-null object
# MATRICULA_ULTIMO_CURSO_MASCULINO       13832 non-null object
# MATRICULA_ULTIMO_CURSO_FEMENINO        13832 non-null object
# MATRICULA_ULTIMO_CURSO_TOTAL           13832 non-null object
# NOMBRE_DIRECTOR                        13717 non-null object
# NOMBRE_ORIENTADOR                      4745 non-null object
# COD_ENSENANZA                          13832 non-null object
# NOMBRE_RELACIONADOR                    4746 non-null object
# ROL_BASE_DATOS                         13832 non-null object
# dtypes: int64(5), object(23)
# memory usage: 3.0+ MB
# None

# %%
# Paso 6: Quitar valores nulos conocidos
p17.replace_null_values(null_dict)

# %%
# Paso 7: Cargar en sql con tipos de datos, si se asignan
p17.to_sql(engine)
# Out:
# 00:16:44.32

# %%
# Opcional
p17.tables_to_sql(engine, ['e'], type_list=True, if_exists='replace')
# Out:
# 00:00:55.01

# %% [markdown]
# ## 2.3 PSU 2016

# %%
# Creación de la instancia
file_path = r'C:\Users\fpalomer\Documents\PSU\PSU_2016.mdb'
p16 = PrepPsuAccess(file_path)

# %%
# Paso 1: Limpiar nombre de las columnas
p16.clean_columns_name()
# Out:
# En p16_a no hubo cambios
# En p16_b no hubo cambios
# En p16_c no hubo cambios
# En p16_e_bea no hubo cambios
# En p16_e_psu no hubo cambios
# En p16_g1 no hubo cambios
# En p16_g1_bea no hubo cambios

# %%
# Paso 2: Homogeneizar nombre de columnas
p16.rename_columns(colname_dict)

# %%
# Paso 3: Transformaciones varias
p16.transform_col(transformer_dict)

# %%
# Paso 4: Remover valores no númericos en columnas númericas
p16.remove_numeric_dirtydata(dtypes_dict)

# %%
# Paso 5: cambio de datos
p16.change_column_dtype(dtypes_dict)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2493 entries, 0 to 2492
# Data columns (total 57 columns):
# NUMERO_DOCUMENTO                         2493 non-null object
# TIPO_DE_IDENTIFICACION                   2493 non-null object
# AÑO_PROCESO                              2493 non-null int64
# MATERNO                                  2493 non-null object
# PATERNO                                  2493 non-null object
# NACIONALIDAD                             2493 non-null int64
# NOMBRE                                   2493 non-null object
# PREFERENCIA                              2493 non-null int64
# SEXO                                     2493 non-null int64
# CODIGO                                   2493 non-null int64
# ESTADO_DE_POSTULACION                    2493 non-null int64
# LUGAR_EN_LA_LISTA                        2493 non-null int64
# PUNTAJE_PONDERADO                        2493 non-null float64
# BEA                                      2493 non-null object
# LOCAL_EDUCACIONAL                        2493 non-null int64
# SITUACION_EGRESO_EDUCACIONAL             2493 non-null int64
# ROL_BASE_DATOS                           2493 non-null int64
# UNIDAD_EDUCATIVA                         2493 non-null int64
# GRUPO_DEPENDENCIA                        2493 non-null int64
# RAMA_EDUCACIONAL                         2493 non-null object
# CODIGO_PROVINCIA                         2493 non-null int64
# CODIGO_REGION                            2493 non-null int64
# AÑO_DE_EGRESO                            2493 non-null int64
# PROMEDIO_DE_NOTAS                        2493 non-null float64
# PTJE_NEM                                 2493 non-null int64
# LENGUAJE_Y_COMUNICACION                  2493 non-null int64
# PTJE_RANKING                             2493 non-null int64
# HISTORIA_Y_CIENCIAS_SOCIALES             2493 non-null int64
# MATEMATICA                               2493 non-null int64
# CIENCIAS                                 2493 non-null int64
# MODULO_CIENCIAS                          2242 non-null object
# FECHA_NACIMIENTO                         2493 non-null object
# PROMLM                                   2493 non-null object
# COBERTURA_SALUD                          2493 non-null object
# INGRESO_BRUTO_FAMILIAR                   2493 non-null int64
# RUT_MADRE                                2493 non-null object
# RUT_PADRE                                2493 non-null object
# CALLE                                    2493 non-null object
# BLOCK                                    223 non-null object
# NUMERO                                   2493 non-null object
# DEPARTAMENTO                             310 non-null object
# COD_REGION                               2493 non-null int64
# VILLA/POBLACION                          1877 non-null object
# COD_COMUNA                               2493 non-null int64
# COD_PROVINCIA                            2493 non-null int64
# NOMBRE_COMUNA                            2493 non-null object
# NOMBRE_PROVINCIA                         2493 non-null object
# CIUDAD                                   2493 non-null object
# COD_AREA                                 2493 non-null object
# NUMERO_TELEFONO                          2493 non-null object
# NUMERO_DE_CELULAR                        2493 non-null object
# PREFIJO_CELULAR                          2493 non-null object
# EMAIL                                    2493 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    2493 non-null object
# NRO_TAJETA_DE_MATRICULA                  2493 non-null object
# Id                                       2493 non-null int64
# POND_AÑO_ACAD                            2493 non-null int64
# dtypes: float64(2), int64(27), object(28)
# memory usage: 1.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21702 entries, 0 to 21701
# Data columns (total 57 columns):
# NUMERO_DOCUMENTO                         21702 non-null object
# TIPO_DE_IDENTIFICACION                   21702 non-null object
# AÑO_PROCESO                              21702 non-null int64
# MATERNO                                  21702 non-null object
# PATERNO                                  21702 non-null object
# NACIONALIDAD                             21702 non-null int64
# NOMBRE                                   21702 non-null object
# PREFERENCIA                              21702 non-null int64
# SEXO                                     21702 non-null int64
# CODIGO                                   21702 non-null int64
# ESTADO_DE_POSTULACION                    21702 non-null int64
# LUGAR_EN_LA_LISTA                        21702 non-null int64
# PUNTAJE_PONDERADO                        21702 non-null float64
# BEA                                      3379 non-null object
# LOCAL_EDUCACIONAL                        21702 non-null int64
# SITUACION_EGRESO_EDUCACIONAL             21702 non-null int64
# ROL_BASE_DATOS                           21702 non-null int64
# UNIDAD_EDUCATIVA                         21702 non-null int64
# GRUPO_DEPENDENCIA                        21702 non-null int64
# RAMA_EDUCACIONAL                         21693 non-null object
# CODIGO_PROVINCIA                         21702 non-null int64
# CODIGO_REGION                            21702 non-null int64
# AÑO_DE_EGRESO                            21702 non-null int64
# PROMEDIO_DE_NOTAS                        21702 non-null float64
# PTJE_NEM                                 21702 non-null int64
# LENGUAJE_Y_COMUNICACION                  21702 non-null int64
# PTJE_RANKING                             21702 non-null int64
# HISTORIA_Y_CIENCIAS_SOCIALES             21702 non-null int64
# MATEMATICA                               21702 non-null int64
# CIENCIAS                                 21702 non-null int64
# MODULO_CIENCIAS                          16372 non-null object
# FECHA_NACIMIENTO                         21702 non-null object
# PROMLM                                   21702 non-null object
# COBERTURA_SALUD                          21702 non-null object
# INGRESO_BRUTO_FAM                        21702 non-null object
# RUT_MADRE                                21702 non-null object
# RUT_PADRE                                21702 non-null object
# CALLE                                    21702 non-null object
# BLOCK                                    2109 non-null object
# NUMERO                                   21702 non-null object
# DEPARTAMENTO                             4226 non-null object
# COD_REGION                               21702 non-null int64
# VILLA/POBLACION                          13000 non-null object
# COD_COMUNA                               21702 non-null int64
# COD_PROVINCIA                            21702 non-null int64
# NOMBRE_COMUNA                            21702 non-null object
# NOMBRE_PROVINCIA                         21702 non-null object
# CIUDAD                                   21702 non-null object
# COD_AREA                                 21702 non-null object
# NUMERO_TELEFONO                          21702 non-null object
# NUMERO_DE_CELULAR                        21702 non-null object
# PREFIJO_CELULAR                          21702 non-null object
# EMAIL                                    21702 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    21702 non-null object
# NRO_TAJETA_DE_MATRICULA                  21702 non-null object
# Id                                       21702 non-null int64
# POND_AÑO_ACAD                            21702 non-null int64
# dtypes: float64(2), int64(26), object(29)
# memory usage: 9.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267234 entries, 0 to 267233
# Data columns (total 29 columns):
# NUMERO_DOCUMENTO                              267232 non-null object
# TIPO_DE_IDENTIFICACION                        267232 non-null object
# AÑO_DOCUMENTO                                 267232 non-null object
# LOCAL_EDUCACIONAL                             267231 non-null float64
# SITUACION_EGRESO_EDUCACIONAL                  267232 non-null object
# ROL_BASE_DATOS                                267232 non-null object
# UNIDAD_EDUCATIVA                              267231 non-null float64
# GRUPO_DEPENDENCIA                             267231 non-null object
# RAMA_EDUCACIONAL                              267071 non-null object
# CODIGO_PROVINCIA                              267231 non-null float64
# CODIGO_REGION                                 267231 non-null float64
# AÑO_EGRESO_ENSEÑANZA_MEDIA                    267231 non-null object
# BEA                                           16911 non-null object
# PROMEDIO_NOTAS                                267231 non-null float64
# PTJE_NEM                                      267231 non-null float64
# PTJE_LENGUAJE_Y_COMUNICACION_ACTUAL           267231 non-null float64
# PTJE_RANKING                                  267231 non-null float64
# PTJE_HISTORIA_Y_CIENCIAS_SOCIALES_ACTUAL      267231 non-null float64
# PTJE_MATEMATICA_ACTUAL                        267231 non-null float64
# MODULO_CIENCIAS_ACTUAL                        157741 non-null object
# PTJE_CIENCIAS_ACTUAL                          267231 non-null float64
# PROMLM                                        267231 non-null object
# PTJE_LENGUAJE_Y_COMUNICACION_ANTERIOR         267231 non-null object
# PTJE_HISTORIA_Y_CIENCIAS_SOCIALES_ANTERIOR    267231 non-null object
# PTJE_MATEMATICA_ANTERIOR                      267231 non-null object
# MODULO_CIENCIAS_ANTERIOR                      27978 non-null object
# PTJE_CIENCIAS_ANTERIOR                        267231 non-null object
# Id                                            267234 non-null int64
# PROMLM_ANTERIOR                               267231 non-null object
# dtypes: float64(11), int64(1), object(17)
# memory usage: 59.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299787 entries, 0 to 299786
# Data columns (total 56 columns):
# NUMERO_DOCUMENTO                         299784 non-null object
# TIPO_DE_IDENTIFICACION                   299784 non-null object
# AÑO_PROCESO                              299784 non-null object
# MATERNO                                  299783 non-null object
# PATERNO                                  299784 non-null object
# NACIONALIDAD                             299783 non-null object
# NOMBRES                                  299783 non-null object
# LOCAL_EDUCATIVA                          299783 non-null object
# SEXO                                     299783 non-null object
# ROL_BASE_DATOS                           299783 non-null object
# UNIDAD_EDUCATIVA                         299783 non-null object
# CODIGO_PROVINCIA                         299783 non-null object
# CODIGO_REGION                            299783 non-null object
# AÑO_EGRESO_ENSEÑANZA_MEDIA               299783 non-null object
# ESTADO_CIVIL                             299783 non-null object
# FECHA_NACIMIENTO                         299783 non-null object
# HORARIO_TRABAJO                          299783 non-null object
# TIENE_TRABAJO_REM                        299783 non-null object
# DE_PROSEGUIR_ESTUDIOS                    299783 non-null object
# HORAS_QUE_DEDICA_TRABAJO                 299783 non-null object
# CUANTOS_TRABAJAN_GRUPO_FAMILIAR          299783 non-null object
# GRUPO_FAMILIAR                           299783 non-null object
# QUIEN_ES_EL_JEFE_DE_FAMILIA              299783 non-null object
# CUANTOS_ESTUDIAN_GRUPO_FAMILIAR          299783 non-null object
# QUIEN_FINANCIARA_ESTUDIOS                299783 non-null object
# COBERTURA_SALUD                          299783 non-null object
# INGRESO_BRUTO_FAMILIAR                   299783 non-null float64
# ¿VIVEN_SUS_PADRES?                       299783 non-null object
# EDUCACION_DE_LOS_PADRES                  299783 non-null object
# SITUACION_OCUPACIONAL                    299783 non-null object
# OCUPACION_PRINCIPAL                      299783 non-null object
# TIPO_ORGANISMO_TRABAJAN                  299783 non-null object
# RAMA_ACTIVIDAD                           299783 non-null object
# RUT_MADRE                                299783 non-null object
# RUT_PADRE                                299783 non-null object
# CALLE                                    299783 non-null object
# BLOCK                                    25764 non-null object
# NUMERO                                   299783 non-null object
# DEPARTAMENTO                             37449 non-null object
# COD_REGION                               299783 non-null object
# VILLA/POBLACION                          224078 non-null object
# COD_COMUNA                               299783 non-null object
# COD_PROVINCIA                            299783 non-null object
# NOMBRE_COMUNA                            299783 non-null object
# NOMBRE_PROVINCIA                         299783 non-null object
# CIUDAD                                   299783 non-null object
# CODIGO_AREA                              299783 non-null object
# NUMERO_TELEFONO                          299783 non-null object
# NUMERO_CELULAR                           299783 non-null object
# PREFIJO_CELULAR                          299783 non-null object
# EMAIL                                    299768 non-null object
# BEA                                      17398 non-null object
# NRO_TARJETA_MATRICULA                    299783 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    299783 non-null object
# Id                                       299787 non-null int64
# INSCRITO_PROCESO                         299783 non-null object
# dtypes: float64(1), int64(1), object(54)
# memory usage: 128.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2493 entries, 0 to 2492
# Data columns (total 57 columns):
# NUMERO_DOCUMENTO                         2493 non-null object
# TIPO_DE_IDENTIFICACION                   2493 non-null object
# AÑO_PROCESO                              2493 non-null int64
# MATERNO                                  2493 non-null object
# PATERNO                                  2493 non-null object
# NACIONALIDAD                             2493 non-null int64
# NOMBRE                                   2493 non-null object
# PREFERENCIA                              2493 non-null int64
# SEXO                                     2493 non-null int64
# CODIGO                                   2493 non-null int64
# ESTADO_DE_POSTULACION                    2493 non-null int64
# LUGAR_EN_LA_LISTA                        2493 non-null int64
# PUNTAJE_PONDERADO                        2493 non-null float64
# BEA                                      2493 non-null object
# LOCAL_EDUCACIONAL                        2493 non-null int64
# SITUACION_EGRESO_EDUCACIONAL             2493 non-null int64
# ROL_BASE_DATOS                           2493 non-null int64
# UNIDAD_EDUCATIVA                         2493 non-null int64
# GRUPO_DEPENDENCIA                        2493 non-null int64
# RAMA_EDUCACIONAL                         2493 non-null object
# CODIGO_PROVINCIA                         2493 non-null int64
# CODIGO_REGION                            2493 non-null int64
# AÑO_DE_EGRESO                            2493 non-null int64
# PROMEDIO_DE_NOTAS                        2493 non-null float64
# PTJE_NEM                                 2493 non-null int64
# LENGUAJE_Y_COMUNICACION                  2493 non-null int64
# PTJE_RANKING                             2493 non-null int64
# HISTORIA_Y_CIENCIAS_SOCIALES             2493 non-null int64
# MATEMATICA                               2493 non-null int64
# CIENCIAS                                 2493 non-null int64
# MODULO_CIENCIAS                          2242 non-null object
# FECHA_NACIMIENTO                         2493 non-null object
# PROMLM                                   2493 non-null object
# COBERTURA_SALUD                          2493 non-null object
# INGRESO_BRUTO_FAMILIAR                   2493 non-null int64
# RUT_MADRE                                2493 non-null object
# RUT_PADRE                                2493 non-null object
# CALLE                                    2493 non-null object
# BLOCK                                    223 non-null object
# NUMERO                                   2493 non-null object
# DEPARTAMENTO                             310 non-null object
# COD_REGION                               2493 non-null int64
# VILLA/POBLACION                          1877 non-null object
# COD_COMUNA                               2493 non-null int64
# COD_PROVINCIA                            2493 non-null int64
# NOMBRE_COMUNA                            2493 non-null object
# NOMBRE_PROVINCIA                         2493 non-null object
# CIUDAD                                   2493 non-null object
# COD_AREA                                 2493 non-null object
# NUMERO_TELEFONO                          2493 non-null object
# NUMERO_DE_CELULAR                        2493 non-null object
# PREFIJO_CELULAR                          2493 non-null object
# EMAIL                                    2493 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    2493 non-null object
# NRO_TAJETA_DE_MATRICULA                  2493 non-null object
# Id                                       2493 non-null int64
# POND_AÑO_ACAD                            2493 non-null int64
# dtypes: float64(2), int64(27), object(28)
# memory usage: 1.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2496 entries, 0 to 2495
# Data columns (total 20 columns):
# NUMERO_DOCUMENTO          2494 non-null object
# TIPO_DE_IDENTIFICACION    2494 non-null object
# AÑO_PROCESO               2494 non-null object
# MATERNO                   2493 non-null object
# PATERNO                   2494 non-null object
# NOMBRES                   2493 non-null object
# CODIGO_CARRERA            2493 non-null object
# PREFERENCIA               2493 non-null object
# NOMBRE_CARRERA            2493 non-null object
# SIGLA_UNIVERSIDAD         2493 non-null object
# VACANTES                  2493 non-null object
# NOMBRE_UNIVERSIDAD        2493 non-null object
# PUNTAJE                   2493 non-null object
# SITUACION                 2493 non-null object
# BEA                       2493 non-null object
# LUGAR                     2493 non-null object
# EMAIL                     2493 non-null object
# FECHA_NACIMIENTO          2493 non-null object
# Id                        2496 non-null int64
# POND_AÑO_ACAD             2493 non-null object
# dtypes: int64(1), object(19)
# memory usage: 390.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12880 entries, 0 to 12879
# Data columns (total 31 columns):
# Id                                     12880 non-null int64
# AÑO_PROCESO                            12876 non-null float64
# LOCAL_EDUCATIVA                        12877 non-null float64
# UNIDAD_EDUCATIVA                       12877 non-null float64
# NOMBRE_OFICIAL                         12878 non-null object
# CODIGO_REGION                          12876 non-null object
# CODIGO_PROVINCIA                       12876 non-null object
# CODIGO_COMUNA                          12876 non-null float64
# CODIGO_POSTAL                          12876 non-null object
# DISCADO_DIRECTO                        12876 non-null object
# FONO_PRINCIPAL                         12876 non-null object
# FAX                                    12876 non-null object
# EMAIL                                  4746 non-null object
# DIRECCION                              12876 non-null object
# DEPENDENCIA                            12876 non-null object
# RAMA_EDUCACIONAL                       12876 non-null object
# REGIMEN                                12876 non-null object
# GRUPO_DEPENDENCIA                      12876 non-null object
# MATRICULA_PENULTIMO_CURSO_MASCULINO    12876 non-null object
# MATRICULA_PENULTIMO_CURSO_FEMENINO     12876 non-null object
# MATRICULA_PENULTIMO_CURSO_TOTAL        12876 non-null object
# MATRICULA_ULTIMO_CURSO_MASCULINO       12876 non-null object
# MATRICULA_ULTIMO_CURSO_FEMENINO        12876 non-null object
# MATRICULA_ULTIMO_CURSO_TOTAL           12876 non-null object
# NOMBRE_DIRECTOR                        11787 non-null object
# NOMBRE_ORIENTADOR                      4746 non-null object
# COD_ENSENANZA                          12876 non-null object
# NOMBRE_RELACIONADOR                    4746 non-null object
# ROL_BASE_DATOS                         12876 non-null object
# PNC                                    12876 non-null object
# PMNC                                   12876 non-null object
# dtypes: float64(4), int64(1), object(26)
# memory usage: 3.0+ MB
# None

# %%
# Paso 6: Quitar valores nulos conocidos
p16.replace_null_values(null_dict)

# %%
# Paso 7: Cargar en sql con tipos de datos, si se asignan
p16.to_sql(engine)
# Out:
# 00:15:22.99

# %%
# Opcional
p16.tables_to_sql(engine, ['e'], type_list=True, if_exists='replace')
# Out:
# 00:00:55.18

# %% [markdown]
# ## 2.4 PSU 2015

# %%
# Creación de la instancia
file_path = r'C:\Users\fpalomer\Documents\PSU\PSU_2015.mdb'
p15 = PrepPsuAccess(file_path)

# %%
# Paso 1: Limpiar nombre de las columnas
p15.clean_columns_name()
# Out:
# En p15_a no hubo cambios
# En p15_b no hubo cambios
# En p15_c no hubo cambios
# En p15_d no hubo cambios
# En p15_d_bea no hubo cambios
# En p15_e_bea no hubo cambios
# En p15_e_psu no hubo cambios
# For p15_f
# cols {'PROM_LM ACTUAL'}
# converted to
#  cols{'PROM_LM_ACTUAL'}
#
# En p15_g no hubo cambios
# En p15_g_bea no hubo cambios
# En p15_g1 no hubo cambios
# En p15_g1_bea no hubo cambios

# %%
# Paso 2: Homogeneizar nombre de columnas
p15.rename_columns(colname_dict)

# %%
# Paso 3: Transformaciones varias
p15.transform_col(transformer_dict)

# %%
# Paso 4: Remover valores no númericos en columnas númericas
p15.remove_numeric_dirtydata(dtypes_dict)

# %%
# Paso 5: cambio de datos
p15.change_column_dtype(dtypes_dict)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2086 entries, 0 to 2085
# Data columns (total 57 columns):
# NUMERO_DOCUMENTO                         2084 non-null object
# TIPO_DE_IDENTIFICACION                   2084 non-null object
# AÑO_PROCESO                              2082 non-null float64
# MATERNO                                  2082 non-null object
# PATERNO                                  2083 non-null object
# NACIONALIDAD                             2082 non-null float64
# NOMBRE                                   2082 non-null object
# PREFERENCIA                              2082 non-null float64
# SEXO                                     2082 non-null float64
# CODIGO                                   2082 non-null float64
# ESTADO_DE_POSTULACION                    2082 non-null float64
# LUGAR_EN_LA_LISTA                        2082 non-null float64
# PUNTAJE_PONDERADO                        2082 non-null float64
# BEA                                      2082 non-null object
# LOCAL_EDUCACIONAL                        2082 non-null float64
# SITUACION_EGRESO_EDUCACIONAL             2082 non-null float64
# ROL_BASE_DATOS                           2082 non-null float64
# UNIDAD_EDUCATIVA                         2082 non-null float64
# GRUPO_DEPENDENCIA                        2082 non-null float64
# RAMA_EDUCACIONAL                         2082 non-null object
# CODIGO_PROVINCIA                         2082 non-null float64
# CODIGO_REGION                            2082 non-null float64
# AÑO_DE_EGRESO                            2082 non-null float64
# PROMEDIO_DE_NOTAS                        2082 non-null float64
# PTJE_NEM                                 2082 non-null float64
# LENGUAJE_Y_COMUNICACION                  2082 non-null float64
# PTJE_RANKING                             2082 non-null float64
# HISTORIA_Y_CIENCIAS_SOCIALES             2082 non-null float64
# MATEMATICA                               2082 non-null float64
# CIENCIAS                                 2082 non-null float64
# MODULO_CIENCIAS                          1826 non-null object
# FECHA_NACIMIENTO                         2082 non-null object
# PROMLM                                   2082 non-null object
# COBERTURA_SALUD                          2082 non-null object
# INGRESO_BRUTO_FAMILIAR                   2082 non-null float64
# RUT_MADRE                                2082 non-null object
# RUT_PADRE                                2082 non-null object
# CALLE                                    2082 non-null object
# BLOCK                                    194 non-null object
# NUMERO                                   2082 non-null object
# DEPARTAMENTO                             253 non-null object
# COD_REGION                               2082 non-null float64
# VILLA/POBLACION                          1527 non-null object
# COD_COMUNA                               2082 non-null float64
# COD_PROVINCIA                            2082 non-null float64
# NOMBRE_COMUNA                            2082 non-null object
# NOMBRE_PROVINCIA                         2082 non-null object
# CIUDAD                                   2082 non-null object
# COD_AREA                                 2082 non-null object
# NUMERO_TELEFONO                          2082 non-null object
# NUMERO_DE_CELULAR                        2082 non-null object
# PREFIJO_CELULAR                          2082 non-null object
# EMAIL                                    2082 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    2082 non-null object
# NRO_TAJETA_DE_MATRICULA                  2082 non-null object
# Id                                       2086 non-null int64
# POND_AÑO_ACAD                            2082 non-null float64
# dtypes: float64(28), int64(1), object(28)
# memory usage: 929.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18186 entries, 0 to 18185
# Data columns (total 57 columns):
# NUMERO_DOCUMENTO                         18184 non-null object
# TIPO_DE_IDENTIFICACION                   18184 non-null object
# AÑO_PROCESO                              18182 non-null float64
# MATERNO                                  18182 non-null object
# PATERNO                                  18183 non-null object
# NACIONALIDAD                             18182 non-null float64
# NOMBRE                                   18182 non-null object
# PREFERENCIA                              18182 non-null float64
# SEXO                                     18182 non-null float64
# CODIGO                                   18182 non-null float64
# ESTADO_DE_POSTULACION                    18182 non-null float64
# LUGAR_EN_LA_LISTA                        18182 non-null float64
# PUNTAJE_PONDERADO                        18182 non-null float64
# BEA                                      3233 non-null object
# LOCAL_EDUCACIONAL                        18182 non-null float64
# SITUACION_EGRESO_EDUCACIONAL             18182 non-null float64
# ROL_BASE_DATOS                           18182 non-null float64
# UNIDAD_EDUCATIVA                         18182 non-null float64
# GRUPO_DEPENDENCIA                        18182 non-null float64
# RAMA_EDUCACIONAL                         18182 non-null object
# CODIGO_PROVINCIA                         18182 non-null float64
# CODIGO_REGION                            18182 non-null float64
# AÑO_DE_EGRESO                            18182 non-null float64
# PROMEDIO_DE_NOTAS                        18182 non-null float64
# PTJE_NEM                                 18182 non-null float64
# LENGUAJE_Y_COMUNICACION                  18182 non-null float64
# PTJE_RANKING                             18182 non-null float64
# HISTORIA_Y_CIENCIAS_SOCIALES             18182 non-null float64
# MATEMATICA                               18182 non-null float64
# CIENCIAS                                 18182 non-null float64
# MODULO_CIENCIAS                          13300 non-null object
# FECHA_NACIMIENTO                         18182 non-null object
# PROMLM                                   18182 non-null object
# COBERTURA_SALUD                          18182 non-null object
# INGRESO_BRUTO_FAM                        18182 non-null object
# RUT_MADRE                                18182 non-null object
# RUT_PADRE                                18182 non-null object
# CALLE                                    18182 non-null object
# BLOCK                                    1596 non-null object
# NUMERO                                   18182 non-null object
# DEPARTAMENTO                             3483 non-null object
# COD_REGION                               18182 non-null float64
# VILLA/POBLACION                          10716 non-null object
# COD_COMUNA                               18182 non-null float64
# COD_PROVINCIA                            18182 non-null float64
# NOMBRE_COMUNA                            18182 non-null object
# NOMBRE_PROVINCIA                         18182 non-null object
# CIUDAD                                   18182 non-null object
# COD_AREA                                 18182 non-null object
# NUMERO_TELEFONO                          18182 non-null object
# NUMERO_DE_CELULAR                        18182 non-null object
# PREFIJO_CELULAR                          18182 non-null object
# EMAIL                                    18182 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    18182 non-null object
# NRO_TAJETA_DE_MATRICULA                  18182 non-null object
# Id                                       18186 non-null int64
# POND_AÑO_ACAD                            18182 non-null float64
# dtypes: float64(27), int64(1), object(29)
# memory usage: 7.9+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258586 entries, 0 to 258585
# Data columns (total 29 columns):
# NUMERO_DOCUMENTO                              258584 non-null object
# TIPO_DE_IDENTIFICACION                        258584 non-null object
# AÑO_DOCUMENTO                                 258584 non-null object
# LOCAL_EDUCACIONAL                             258583 non-null float64
# SITUACION_EGRESO_EDUCACIONAL                  258584 non-null object
# ROL_BASE_DATOS                                258584 non-null object
# UNIDAD_EDUCATIVA                              258583 non-null float64
# GRUPO_DEPENDENCIA                             258583 non-null object
# RAMA_EDUCACIONAL                              258583 non-null object
# CODIGO_PROVINCIA                              258583 non-null float64
# CODIGO_REGION                                 258583 non-null float64
# AÑO_EGRESO_ENSEÑANZA_MEDIA                    258583 non-null object
# BEA                                           16710 non-null object
# PROMEDIO_NOTAS                                258583 non-null float64
# PTJE_NEM                                      258583 non-null float64
# PTJE_LENGUAJE_Y_COMUNICACION_ACTUAL           258583 non-null float64
# PTJE_RANKING                                  258583 non-null float64
# PTJE_HISTORIA_Y_CIENCIAS_SOCIALES_ACTUAL      258583 non-null float64
# PTJE_MATEMATICA_ACTUAL                        258583 non-null float64
# MODULO_CIENCIAS_ACTUAL                        153213 non-null object
# PTJE_CIENCIAS_ACTUAL                          258583 non-null float64
# PROMLM                                        258583 non-null object
# PTJE_LENGUAJE_Y_COMUNICACION_ANTERIOR         258583 non-null object
# PTJE_HISTORIA_Y_CIENCIAS_SOCIALES_ANTERIOR    258583 non-null object
# PTJE_MATEMATICA_ANTERIOR                      258583 non-null object
# MODULO_CIENCIAS_ANTERIOR                      24064 non-null object
# PTJE_CIENCIAS_ANTERIOR                        258583 non-null object
# Id                                            258586 non-null int64
# PROMLM_ANTERIOR                               258583 non-null object
# dtypes: float64(11), int64(1), object(17)
# memory usage: 57.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290196 entries, 0 to 290195
# Data columns (total 56 columns):
# NUMERO_DOCUMENTO                         290194 non-null object
# TIPO_DE_IDENTIFICACION                   290194 non-null object
# AÑO_PROCESO                              290194 non-null object
# MATERNO                                  290193 non-null object
# PATERNO                                  290194 non-null object
# NACIONALIDAD                             290193 non-null object
# NOMBRES                                  290193 non-null object
# LOCAL_EDUCATIVA                          290193 non-null object
# SEXO                                     290193 non-null object
# ROL_BASE_DATOS                           290193 non-null object
# UNIDAD_EDUCATIVA                         290193 non-null object
# CODIGO_PROVINCIA                         290193 non-null object
# CODIGO_REGION                            290193 non-null object
# AÑO_EGRESO_ENSEÑANZA_MEDIA               290193 non-null object
# ESTADO_CIVIL                             290193 non-null object
# FECHA_NACIMIENTO                         290193 non-null object
# HORARIO_TRABAJO                          290193 non-null object
# TIENE_TRABAJO_REM                        290193 non-null object
# DE_PROSEGUIR_ESTUDIOS                    290193 non-null object
# HORAS_QUE_DEDICA_TRABAJO                 290193 non-null object
# CUANTOS_TRABAJAN_GRUPO_FAMILIAR          290193 non-null object
# GRUPO_FAMILIAR                           290193 non-null object
# QUIEN_ES_EL_JEFE_DE_FAMILIA              290193 non-null object
# CUANTOS_ESTUDIAN_GRUPO_FAMILIAR          290193 non-null object
# QUIEN_FINANCIARA_ESTUDIOS                290193 non-null object
# COBERTURA_SALUD                          290193 non-null object
# INGRESO_BRUTO_FAMILIAR                   290193 non-null float64
# ¿VIVEN_SUS_PADRES?                       290193 non-null object
# EDUCACION_DE_LOS_PADRES                  290193 non-null object
# SITUACION_OCUPACIONAL                    290193 non-null object
# OCUPACION_PRINCIPAL                      290193 non-null object
# TIPO_ORGANISMO_TRABAJAN                  290193 non-null object
# RAMA_ACTIVIDAD                           290193 non-null object
# RUT_MADRE                                290193 non-null object
# RUT_PADRE                                290193 non-null object
# CALLE                                    290193 non-null object
# BLOCK                                    23913 non-null object
# NUMERO                                   290193 non-null object
# DEPARTAMENTO                             37070 non-null object
# COD_REGION                               290193 non-null object
# VILLA/POBLACION                          214827 non-null object
# COD_COMUNA                               290193 non-null object
# COD_PROVINCIA                            290193 non-null object
# NOMBRE_COMUNA                            290193 non-null object
# NOMBRE_PROVINCIA                         290193 non-null object
# CIUDAD                                   290193 non-null object
# CODIGO_AREA                              290193 non-null object
# NUMERO_TELEFONO                          290193 non-null object
# NUMERO_CELULAR                           290193 non-null object
# PREFIJO_CELULAR                          290193 non-null object
# EMAIL                                    290160 non-null object
# BEA                                      17089 non-null object
# NRO_TARJETA_MATRICULA                    290193 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    290193 non-null object
# Id                                       290196 non-null int64
# INSCRITO_PROCESO                         290193 non-null object
# dtypes: float64(1), int64(1), object(54)
# memory usage: 124.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4628 entries, 0 to 4627
# Data columns (total 57 columns):
# NUMERO_DOCUMENTO               4626 non-null object
# TIPO_DE_IDENTIFICACION         4626 non-null object
# AÑO_PROCESO                    4626 non-null object
# CODIGO_1                       4626 non-null object
# SITUACION_DEL_POSTULANTE       4626 non-null object
# ESTADO_DE_LA_PREFERENCIA_1     4626 non-null object
# LUGAR_1                        4625 non-null object
# PUNTAJE_1                      4626 non-null object
# CODIGO_2                       4625 non-null object
# POND_AÑO_ACAD_1                4625 non-null object
# ESTADO_DE_LA_PREFERENCIA_2     4625 non-null object
# LUGAR_2                        4625 non-null object
# PUNTAJE_2                      4625 non-null object
# CODIGO_3                       4625 non-null object
# POND_AÑO_ACAD_2                4625 non-null object
# ESTADO_DE_LA_PREFERENCIA_3     4625 non-null object
# LUGAR_3                        4625 non-null object
# PUNTAJE_3                      4625 non-null object
# CODIGO_4                       4625 non-null object
# POND_AÑO_ACAD_3                4625 non-null object
# ESTADO_DE_LA_PREFERENCIA_4     4625 non-null object
# LUGAR_4                        4625 non-null object
# PUNTAJE_4                      4625 non-null object
# CODIGO_5                       4625 non-null object
# POND_AÑO_ACAD_4                4625 non-null object
# ESTADO_DE_LA_PREFERENCIA_5     4625 non-null object
# LUGAR_5                        4625 non-null object
# PUNTAJE_5                      4625 non-null object
# CODIGO_6                       4625 non-null object
# POND_AÑO_ACAD_5                4625 non-null object
# ESTADO_DE_LA_PREFERENCIA_6     4625 non-null object
# LUGAR_6                        4625 non-null object
# PUNTAJE_6                      4625 non-null object
# CODIGO_7                       4625 non-null object
# POND_AÑO_ACAD_6                4625 non-null object
# ESTADO_DE_LA_PREFERENCIA_7     4625 non-null object
# LUGAR_7                        4625 non-null object
# PUNTAJE_7                      4625 non-null object
# CODIGO_8                       4625 non-null object
# POND_AÑO_ACAD_7                4625 non-null object
# ESTADO_DE_LA_PREFERENCIA_8     4625 non-null object
# LUGAR_8                        4625 non-null object
# PUNTAJE_8                      4625 non-null object
# CODIGO_9                       4625 non-null object
# POND_AÑO_ACAD_8                4625 non-null object
# ESTADO_DE_LA_PREFERENCIA_9     4625 non-null object
# LUGAR_9                        4625 non-null object
# PUNTAJE_9                      4625 non-null object
# CODIGO_10                      4625 non-null object
# POND_AÑO_ACAD_9                4625 non-null object
# ESTADO_DE_LA_PREFERENCIA_10    4625 non-null object
# LUGAR_10                       4625 non-null object
# PUNTAJE_10                     4625 non-null object
# BEA                            4625 non-null object
# POND_AÑO_ACAD_10               4625 non-null object
# Id                             4628 non-null int64
# NRO_TARJETA_DE_MATRICULA       4625 non-null object
# dtypes: int64(1), object(56)
# memory usage: 2.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2086 entries, 0 to 2085
# Data columns (total 57 columns):
# NUMERO_DOCUMENTO                         2084 non-null object
# TIPO_DE_IDENTIFICACION                   2084 non-null object
# AÑO_PROCESO                              2082 non-null float64
# MATERNO                                  2082 non-null object
# PATERNO                                  2083 non-null object
# NACIONALIDAD                             2082 non-null float64
# NOMBRE                                   2082 non-null object
# PREFERENCIA                              2082 non-null float64
# SEXO                                     2082 non-null float64
# CODIGO                                   2082 non-null float64
# ESTADO_DE_POSTULACION                    2082 non-null float64
# LUGAR_EN_LA_LISTA                        2082 non-null float64
# PUNTAJE_PONDERADO                        2082 non-null float64
# BEA                                      2082 non-null object
# LOCAL_EDUCACIONAL                        2082 non-null float64
# SITUACION_EGRESO_EDUCACIONAL             2082 non-null float64
# ROL_BASE_DATOS                           2082 non-null float64
# UNIDAD_EDUCATIVA                         2082 non-null float64
# GRUPO_DEPENDENCIA                        2082 non-null float64
# RAMA_EDUCACIONAL                         2082 non-null object
# CODIGO_PROVINCIA                         2082 non-null float64
# CODIGO_REGION                            2082 non-null float64
# AÑO_DE_EGRESO                            2082 non-null float64
# PROMEDIO_DE_NOTAS                        2082 non-null float64
# PTJE_NEM                                 2082 non-null float64
# LENGUAJE_Y_COMUNICACION                  2082 non-null float64
# PTJE_RANKING                             2082 non-null float64
# HISTORIA_Y_CIENCIAS_SOCIALES             2082 non-null float64
# MATEMATICA                               2082 non-null float64
# CIENCIAS                                 2082 non-null float64
# MODULO_CIENCIAS                          1826 non-null object
# FECHA_NACIMIENTO                         2082 non-null object
# PROMLM                                   2082 non-null object
# COBERTURA_SALUD                          2082 non-null object
# INGRESO_BRUTO_FAMILIAR                   2082 non-null float64
# RUT_MADRE                                2082 non-null object
# RUT_PADRE                                2082 non-null object
# CALLE                                    2082 non-null object
# BLOCK                                    194 non-null object
# NUMERO                                   2082 non-null object
# DEPARTAMENTO                             253 non-null object
# COD_REGION                               2082 non-null float64
# VILLA/POBLACION                          1527 non-null object
# COD_COMUNA                               2082 non-null float64
# COD_PROVINCIA                            2082 non-null float64
# NOMBRE_COMUNA                            2082 non-null object
# NOMBRE_PROVINCIA                         2082 non-null object
# CIUDAD                                   2082 non-null object
# COD_AREA                                 2082 non-null object
# NUMERO_TELEFONO                          2082 non-null object
# NUMERO_DE_CELULAR                        2082 non-null object
# PREFIJO_CELULAR                          2082 non-null object
# EMAIL                                    2082 non-null object
# CODIGO_INSTITUCION_EDUCACION_SUPERIOR    2082 non-null object
# NRO_TAJETA_DE_MATRICULA                  2082 non-null object
# Id                                       2086 non-null int64
# POND_AÑO_ACAD                            2082 non-null float64
# dtypes: float64(28), int64(1), object(28)
# memory usage: 929.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9885 entries, 0 to 9884
# Data columns (total 20 columns):
# NUMERO_DOCUMENTO          9883 non-null object
# TIPO_DE_IDENTIFICACION    9883 non-null object
# AÑO_PROCESO               9883 non-null object
# MATERNO                   9882 non-null object
# PATERNO                   9883 non-null object
# NOMBRES                   9882 non-null object
# CODIGO_CARRERA            9882 non-null object
# PREFERENCIA               9882 non-null object
# NOMBRE_CARRERA            9882 non-null object
# SIGLA_UNIVERSIDAD         9882 non-null object
# VACANTES                  9882 non-null object
# NOMBRE_UNIVERSIDAD        9882 non-null object
# PUNTAJE                   9882 non-null object
# SITUACION                 9882 non-null object
# BEA                       9882 non-null object
# LUGAR                     9882 non-null object
# EMAIL                     9882 non-null object
# FECHA_NACIMIENTO          9882 non-null object
# Id                        9885 non-null int64
# POND_AÑO_ACAD             9882 non-null object
# dtypes: int64(1), object(19)
# memory usage: 1.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2086 entries, 0 to 2085
# Data columns (total 20 columns):
# NUMERO_DOCUMENTO          2084 non-null object
# TIPO_DE_IDENTIFICACION    2084 non-null object
# AÑO_PROCESO               2084 non-null object
# MATERNO                   2082 non-null object
# PATERNO                   2083 non-null object
# NOMBRES                   2082 non-null object
# CODIGO_CARRERA            2082 non-null object
# PREFERENCIA               2082 non-null object
# NOMBRE_CARRERA            2082 non-null object
# SIGLA_UNIVERSIDAD         2082 non-null object
# VACANTES                  2082 non-null object
# NOMBRE_UNIVERSIDAD        2082 non-null object
# PUNTAJE                   2082 non-null object
# SITUACION                 2082 non-null object
# BEA                       2082 non-null object
# LUGAR                     2082 non-null object
# EMAIL                     2082 non-null object
# FECHA_NACIMIENTO          2082 non-null object
# Id                        2086 non-null int64
# POND_AÑO_ACAD             2082 non-null object
# dtypes: int64(1), object(19)
# memory usage: 326.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7089 entries, 0 to 7088
# Data columns (total 30 columns):
# LOCAL_EDUCATIVA                        7087 non-null float64
# AÑO_PROCESO                            7086 non-null float64
# UNIDAD_EDUCATIVA                       7086 non-null float64
# CODIGO_REGION                          7086 non-null object
# NOMBRE_OFICIAL                         7087 non-null object
# CODIGO_COMUNA                          7086 non-null float64
# CODIGO_PROVINCIA                       7086 non-null object
# CODIGO_POSTAL                          7086 non-null object
# DISCADO_DIRECTO                        7086 non-null object
# FAX                                    7086 non-null object
# FONO_PRINCIPAL                         7086 non-null object
# DIRECCION                              7086 non-null object
# EMAIL                                  4657 non-null object
# RAMA_EDUCACIONAL                       7086 non-null object
# DEPENDENCIA                            7086 non-null object
# REGIMEN                                7086 non-null object
# GRUPO_DEPENDENCIA                      7086 non-null object
# MATRICULA_PENULTIMO_CURSO_FEMENINO     7086 non-null object
# MATRICULA_PENULTIMO_CURSO_MASCULINO    7086 non-null object
# MATRICULA_PENULTIMO_CURSO_TOTAL        7086 non-null object
# MATRICULA_ULTIMO_CURSO_FEMENINO        7086 non-null object
# MATRICULA_ULTIMO_CURSO_MASCULINO       7086 non-null object
# MATRICULA_ULTIMO_CURSO_TOTAL           7086 non-null object
# NOMBRE_DIRECTOR                        7086 non-null object
# NOMBRE_ORIENTADOR                      4657 non-null object
# NOMBRE_RELACIONADOR                    4657 non-null object
# PNC                                    7086 non-null object
# ROL_BASE_DATOS                         7086 non-null object
# Id                                     7089 non-null int64
# PMNC                                   7086 non-null object
# dtypes: float64(4), int64(1), object(25)
# memory usage: 1.6+ MB
# None

# %%
# Paso 6: Quitar valores nulos conocidos
p15.replace_null_values(null_dict)

# %%
# Paso 7: Cargar en sql con tipos de datos, si se asignan
p15.to_sql(engine)
# Out:
# 00:34:28.91

# %%
# Opcional
p15.tables_to_sql(engine, ['e'], type_list=True, if_exists='replace')
# Out:
# 00:00:41.73
